# %%
'''
Exercicios Pandas
Quais habilidades iremos desenvolver?
- Series
- DataFrame
- Inspecionando um DataFrame / Series
- Seleção de dados
- Manipulando DataFrames
- Ordenação
- GroupBy
'''
import pandas as pd

# %%
'''
Exercício 1
Uma Series (array unidimensional) da biblioteca Pandas pode ser criada utilizando-se o construtor:

pd.Series( data, index, dtype, copy )

Então, podemos criar objetos do tipo Series a partir de array, dicionários, escalares e iteráveis. 
Com base nessas informações responda as questões a seguir.

a) A partir da lista abaixo crie um objeto do tipo Series.

lista = ['a', 'b', 'c', 'd']

Resultado esperado:

0    a
1    b
2    c
3    d
dtype: object

b) A partir da lista anterior obtenha:

10    a
11    b
12    c
13    d
dtype: object

Dica: mude o argumento index.

c) Obtenha a Series abaixo:

0    10
1    10
2    10
3    10
dtype: int64

d) A partir do array,

import numpy as np
array = np.arange(10,20,2)
Obtenha:

1    10.0
2    12.0
3    14.0
4    16.0
5    18.0
dtype: float64
'''
# Out:
# "\nExercício 1\nUma Series (array unidimensional) da biblioteca Pandas pode ser criada utilizando-se o construtor:\n\npd.Series( data, index, dtype, copy )\n\nEntão, podemos criar objetos do tipo Series a partir de array, dicionários, escalares e iteráveis. \nCom base nessas informações responda as questões a seguir.\n\na) A partir da lista abaixo crie um objeto do tipo Series.\n\nlista = ['a', 'b', 'c', 'd']\n\nResultado esperado:\n\n0    a\n1    b\n2    c\n3    d\ndtype: object\n\nb) A partir da lista anterior obtenha:\n\n10    a\n11    b\n12    c\n13    d\ndtype: object\n\nDica: mude o argumento index.\n\nc) Obtenha a Series abaixo:\n\n0    10\n1    10\n2    10\n3    10\ndtype: int64\n\nd) A partir do array,\n\nimport numpy as np\narray = np.arange(10,20,2)\nObtenha:\n\n1    10.0\n2    12.0\n3    14.0\n4    16.0\n5    18.0\ndtype: float64\n"

# %%
A = pd.Series(['a', 'b', 'c', 'd'], dtype= object)
A
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
B = pd.Series(['a', 'b', 'c', 'd'], dtype= object, index=[10, 11, 12, 13]) 
B
# Out:
# 10    a
# 11    b
# 12    c
# 13    d
# dtype: object

# %%
C = pd.Series([10, 10, 10, 10], dtype= int)
C
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# dtype: int64

# %%
import numpy as np
array = np.arange(10,20,2)
D = pd.Series(array, dtype=float)
D
# Out:
# 0    10.0
# 1    12.0
# 2    14.0
# 3    16.0
# 4    18.0
# dtype: float64

# %%
'''
Exercício 2
Uma Series (array unidimensional) da biblioteca Pandas pode ser criada utilizando-se o construtor:

pd.Series( data, index, dtype, copy )

Então, podemos criar objetos do tipo Series a partir de array, dicionários, escalares e iteráveis. 
Com base nessas informações responda as questões a seguir.

a) A partir da lista abaixo crie um objeto do tipo Series.

data = ['k','w','z','y']

Resultado esperado:

0    k
1    w
2    z
3    y
dtype: object

b) A partir do dicionário abaixo crie um objeto do tipo Series.

dic = {'a':10,'b':30,'c':15,'d':12}
Resultado esperado:

a    10
b    30
c    15
d    12
dtype: int64

c) Converta os objetos do tipo Series criados anteriormente para uma lista.

Dica: use o método do pandas to_list().

d) Converta os objetos do tipo Series criados nas letras a) e b) para DataFrame. 
Coloque um nome para as colunas. Use o construtor pd.DataFrame().

Resultados esperados:

Letras
0	k
1	w
2	z
3	y

Valores
a	10
b	30
c	15
d	12
'''
# Out:
# "\nExercício 2\nUma Series (array unidimensional) da biblioteca Pandas pode ser criada utilizando-se o construtor:\n\npd.Series( data, index, dtype, copy )\n\nEntão, podemos criar objetos do tipo Series a partir de array, dicionários, escalares e iteráveis. \nCom base nessas informações responda as questões a seguir.\n\na) A partir da lista abaixo crie um objeto do tipo Series.\n\ndata = ['k','w','z','y']\n\nResultado esperado:\n\n0    k\n1    w\n2    z\n3    y\ndtype: object\n\nb) A partir do dicionário abaixo crie um objeto do tipo Series.\n\ndic = {'a':10,'b':30,'c':15,'d':12}\nResultado esperado:\n\na    10\nb    30\nc    15\nd    12\ndtype: int64\n\nc) Converta os objetos do tipo Series criados anteriormente para uma lista.\n\nDica: use o método do pandas to_list().\n\nd) Converta os objetos do tipo Series criados nas letras a) e b) para DataFrame. \nColoque um nome para as colunas. Use o construtor pd.DataFrame().\n\nResultados esperados:\n\nLetras\n0\tk\n1\tw\n2\tz\n3\ty\n\nValores\na\t10\nb\t30\nc\t15\nd\t12\n"

# %%
A = pd.Series(['k', 'w', 'z', 'y'], dtype=object)
A
# Out:
# 0    k
# 1    w
# 2    z
# 3    y
# dtype: object

# %%
B = pd.Series({'a':10,'b':30,'c':15,'d':12}, dtype=int)
B
# Out:
# a    10
# b    30
# c    15
# d    12
# dtype: int64

# %%
#ou
dic = {'a':10,'b':30,'c':15,'d':12}
B = pd.Series(dic, dtype=int)
B
# Out:
# a    10
# b    30
# c    15
# d    12
# dtype: int64

# %%
C = A.to_list()
C
# Out:
# ['k', 'w', 'z', 'y']

# %%
C = B.to_list()
C
# Out:
# [10, 30, 15, 12]

# %%
D = pd.DataFrame(A,columns=['Letras'])
D
# Out:
#   Letras
# 0      k
# 1      w
# 2      z
# 3      y

# %%
D = pd.DataFrame(B,columns=['Valores'])
D
# Out:
#    Valores
# a       10
# b       30
# c       15
# d       12

# %%
'''
Utilize a biblioteca NumPy para criar o objeto do tipo Series a seguir.
25     1.0
26     3.0
27     5.0
28     7.0
29     9.0
30    11.0
31    13.0
32    15.0
33    17.0
34    19.0
35    21.0
36    23.0
37    25.0
38    27.0
39    29.0
40    31.0
41    33.0
42    35.0
43    37.0
44    39.0
45    41.0
46    43.0
47    45.0
48    47.0
49    49.0
Name: Serie, dtype: float64
'''
# Out:
# '\nUtilize a biblioteca NumPy para criar o objeto do tipo Series a seguir.\n25     1.0\n26     3.0\n27     5.0\n28     7.0\n29     9.0\n30    11.0\n31    13.0\n32    15.0\n33    17.0\n34    19.0\n35    21.0\n36    23.0\n37    25.0\n38    27.0\n39    29.0\n40    31.0\n41    33.0\n42    35.0\n43    37.0\n44    39.0\n45    41.0\n46    43.0\n47    45.0\n48    47.0\n49    49.0\nName: Serie, dtype: float64\n'

# %%
import numpy as np
import pandas as pd
array = np.arange(1, 50, 2)
series = pd.Series(array, index = range(25, 50), dtype=float, name = 'Serie')
series
# Out:
# 25     1.0
# 26     3.0
# 27     5.0
# 28     7.0
# 29     9.0
# 30    11.0
# 31    13.0
# 32    15.0
# 33    17.0
# 34    19.0
# 35    21.0
# 36    23.0
# 37    25.0
# 38    27.0
# 39    29.0
# 40    31.0
# 41    33.0
# 42    35.0
# 43    37.0
# 44    39.0
# 45    41.0
# 46    43.0
# 47    45.0
# 48    47.0
# 49    49.0
# Name: Serie, dtype: float64

# %%
'''
Exercício 4
a) A partir da lista a seguir crie um objeto do tipo Series com o pandas.

data = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']
Resultado esperado:

1     ITUB4
2     BBDC4
3     BBAS3
4    BPAC11
5    SANB11
Name: Prices, dtype: object

b) Converta a Series em um dicionário.

c) Converta a Series em uma lista.

d) Converta a Series em um objeto numpy.ndarray.
'''
# Out:
# "\nExercício 4\na) A partir da lista a seguir crie um objeto do tipo Series com o pandas.\n\ndata = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']\nResultado esperado:\n\n1     ITUB4\n2     BBDC4\n3     BBAS3\n4    BPAC11\n5    SANB11\nName: Prices, dtype: object\n\nb) Converta a Series em um dicionário.\n\nc) Converta a Series em uma lista.\n\nd) Converta a Series em um objeto numpy.ndarray.\n"

# %%
data = ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']
A= pd.Series(data, dtype=object)
A
# Out:
# 0     ITUB4
# 1     BBDC4
# 2     BBAS3
# 3    BPAC11
# 4    SANB11
# dtype: object

# %%
B = A.to_dict()
B
# Out:
# {0: 'ITUB4', 1: 'BBDC4', 2: 'BBAS3', 3: 'BPAC11', 4: 'SANB11'}

# %%
C = A.to_list()
C
# Out:
# ['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11']

# %%
D = A.to_numpy()
D
# Out:
# array(['ITUB4', 'BBDC4', 'BBAS3', 'BPAC11', 'SANB11'], dtype=object)

# %%
'''
Exercício 5
a) A partir do dicionário abaixo, crie um objeto do tipo Series e armazene em uma variável. 
Em seguida, converta o objeto criado para uma lista. 
Por fim, crie um DataFrame com os dados disponíveis.

dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }

b) Acrescente os novos valores a Series criada:

RAIL3: 18.93
SUZB3: 48.19
MGLU3: 25.59
'''
# Out:
# "\nExercício 5\na) A partir do dicionário abaixo, crie um objeto do tipo Series e armazene em uma variável. \nEm seguida, converta o objeto criado para uma lista. \nPor fim, crie um DataFrame com os dados disponíveis.\n\ndados={\n    'ABEV3':12.85,\n    'AZUL4':22.55,\n    'BTOW3':115.08,\n    'RENT3':49.03,\n    'JBSS3':24.41,\n    }\n\nb) Acrescente os novos valores a Series criada:\n\nRAIL3: 18.93\nSUZB3: 48.19\nMGLU3: 25.59\n"

# %%
dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }
A = pd.Series(dados)
lista = A.to_list()
df = pd.DataFrame(A, columns=['Preços'])
print(A)
print(df)
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# dtype: float64
#        Preços
# ABEV3   12.85
# AZUL4   22.55
# BTOW3  115.08
# RENT3   49.03
# JBSS3   24.41

# %%
A['RAIL3'] = 18.93
A['SUZB3'] = 48.19
A['MGLU3'] = 25.59
A
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# RAIL3     18.93
# SUZB3     48.19
# MGLU3     25.59
# dtype: float64

# %%
'''
Exercício 6
Adicione os três novos valores a Series abaixo.
PETR4:22,97;
NTCO3:50,60;
TIMP3:14,82.
   
dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }
 
serie = pd.Series(dados)
Resultado esperado:
ABEV3     12.85
AZUL4     22.55
BTOW3    115.08
RENT3     49.03
JBSS3     24.41
PETR4     22.97
NTCO3     50.60
TIMP3     14.82
dtype: float64
'''
# Out:
# "\nExercício 6\nAdicione os três novos valores a Series abaixo.\nPETR4:22,97;\nNTCO3:50,60;\nTIMP3:14,82.\n   \ndados={\n    'ABEV3':12.85,\n    'AZUL4':22.55,\n    'BTOW3':115.08,\n    'RENT3':49.03,\n    'JBSS3':24.41,\n    }\n \nserie = pd.Series(dados)\nResultado esperado:\nABEV3     12.85\nAZUL4     22.55\nBTOW3    115.08\nRENT3     49.03\nJBSS3     24.41\nPETR4     22.97\nNTCO3     50.60\nTIMP3     14.82\ndtype: float64\n"

# %%
dados={
    'ABEV3':12.85,
    'AZUL4':22.55,
    'BTOW3':115.08,
    'RENT3':49.03,
    'JBSS3':24.41,
    }
series = pd.Series(dados)
series['PETR4'] = 22.97
series['NTCO3'] = 50.60
series['TIMP3'] = 14.82
series
# Out:
# ABEV3     12.85
# AZUL4     22.55
# BTOW3    115.08
# RENT3     49.03
# JBSS3     24.41
# PETR4     22.97
# NTCO3     50.60
# TIMP3     14.82
# dtype: float64

# %%
'''
Crie as Series abaixo.
A:
A     1
B     3
C     5
D     7
E     9
F    11
G    13
H    15
I    17
J    19
dtype: int64
B:
F     5
G    10
H    15
I    20
J    25
K    30
L    35
M    40
N    45
dtype: int64
'''
# Out:
# '\nCrie as Series abaixo.\nA:\nA     1\nB     3\nC     5\nD     7\nE     9\nF    11\nG    13\nH    15\nI    17\nJ    19\ndtype: int64\nB:\nF     5\nG    10\nH    15\nI    20\nJ    25\nK    30\nL    35\nM    40\nN    45\ndtype: int64\n'

# %%
import numpy as np
A = pd.Series(
    data = np.arange(1, 20, 2), 
    index = [chr(65+i) for i in range(10)])
A
# Out:
# A     1
# B     3
# C     5
# D     7
# E     9
# F    11
# G    13
# H    15
# I    17
# J    19
# dtype: int64

# %%
B = pd.Series(
    data = np.arange(5, 50, 5),
    index = [chr(70+i) for i in range(9)])
B
# Out:
# F     5
# G    10
# H    15
# I    20
# J    25
# K    30
# L    35
# M    40
# N    45
# dtype: int64

# %%
'''
Exercício 8
Construa o objeto Series abaixo e utilize o método .plot() para gerar um gráfico do objeto criado.

2020    2197
2010    1728
2000    1331
1990    1000
1980     729
1970     512
1960     343
1950     216
1940     125
1930      64
1920      27
1910       8
1900       1
Name: Crescimento no tempo, dtype: int64

- GRAFICO DE TAXA DE CRESCIMENTO DE TEMPO EM LINHA
'''
# Out:
# '\nExercício 8\nConstrua o objeto Series abaixo e utilize o método .plot() para gerar um gráfico do objeto criado.\n\n2020    2197\n2010    1728\n2000    1331\n1990    1000\n1980     729\n1970     512\n1960     343\n1950     216\n1940     125\n1930      64\n1920      27\n1910       8\n1900       1\nName: Crescimento no tempo, dtype: int64\n\n- GRAFICO DE TAXA DE CRESCIMENTO DE TEMPO EM LINHA\n'

# %%
anos = list(range(1900, 2021, 10))
valores = [i**3 for i in range(1,14)]
series = pd.Series(data = valores, index = anos, name = 'Crescimento no tempo')[::-1]
print(series)
# Out:
# 2020    2197
# 2010    1728
# 2000    1331
# 1990    1000
# 1980     729
# 1970     512
# 1960     343
# 1950     216
# 1940     125
# 1930      64
# 1920      27
# 1910       8
# 1900       1
# Name: Crescimento no tempo, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(series)
plt.title('taxa de Crescimento no tempo');

# %%
'''
Exercício 9
Com base na Series abaixo,
import pandas as pd
s = pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])

Faça:

a) mostre o primeiro elemento;

b) mostre o terceiro elemento;

c) mostre os três primeiros elementos;

d) mostre os três últimos elementos;

e) mostre o último elemento.
'''
# Out:
# "\nExercício 9\nCom base na Series abaixo,\nimport pandas as pd\ns = pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])\n\nFaça:\n\na) mostre o primeiro elemento;\n\nb) mostre o terceiro elemento;\n\nc) mostre os três primeiros elementos;\n\nd) mostre os três últimos elementos;\n\ne) mostre o último elemento.\n"

# %%
s = pd.Series([1, 2, 3, 4, 5, 6], index=['a', 'b', 'c', 'd', 'e', 'f'])

# %%
A = s[0]
A
# Out:
# 1

# %%
B = s[2]
B
# Out:
# 3

# %%
C = s[:3]
C
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
D = s[-3:]
D
# Out:
# d    4
# e    5
# f    6
# dtype: int64

# %%
E = s[-1]
E
# Out:
# 6

# %%
'''
Crie uma Series e acesse os seguintes atributos: axes, dtype, empty, ndim, size e values.
Sendo que:

pd.Series().axes : retorna uma lista com os índices da Series;

pd.Series().empty: retorna um valor booleano, informando se o objeto é vazio ou não;

pd.Series().ndim: retorna o número de dimensões do objeto;

pd.Series().size: retorna o tamanho da Series;

pd.Series().values: retorna os dados em um objeto NumPy (ndarray)
'''
# Out:
# '\nCrie uma Series e acesse os seguintes atributos: axes, dtype, empty, ndim, size e values.\nSendo que:\n\npd.Series().axes : retorna uma lista com os índices da Series;\n\npd.Series().empty: retorna um valor booleano, informando se o objeto é vazio ou não;\n\npd.Series().ndim: retorna o número de dimensões do objeto;\n\npd.Series().size: retorna o tamanho da Series;\n\npd.Series().values: retorna os dados em um objeto NumPy (ndarray)\n'

# %%
s = pd.Series(np.random.randn(5))
print(s.axes)
print(s.empty)
print(s.ndim) 
print(s.size)
print(s.values)
# Out:
# [RangeIndex(start=0, stop=5, step=1)]
# False
# 1
# 5
# [-1.02514686 -0.16963276  0.80359257 -0.30708821  0.58141829]

# %%
'''
Exercício 11
Construa o DataFrame abaixo e armazene em uma variável.

	A
0	10
1	22
2	3
3	11
4	17
5	22
6	9
7	4
8	29
9	31
'''
# Out:
# '\nExercício 11\nConstrua o DataFrame abaixo e armazene em uma variável.\n\n\tA\n0\t10\n1\t22\n2\t3\n3\t11\n4\t17\n5\t22\n6\t9\n7\t4\n8\t29\n9\t31\n'

# %%
series = pd.Series([10, 22, 3, 11, 17, 22, 9, 4, 29, 31])
df = pd.DataFrame(series, columns = ['A'])
df
# Out:
#     A
# 0  10
# 1  22
# 2   3
# 3  11
# 4  17
# 5  22
# 6   9
# 7   4
# 8  29
# 9  31

# %%
'''
Exercício 12
Construa um objeto do tipo DataFrame com a estrutura abaixo e armazene em uma variável. 
Coloque os dados em um dicionário Python.
    A  B    C
0  11  1  130
1  33  2  144
2  11  3  111
3  -1  4  104
4   0  5  199
'''
# Out:
# '\nExercício 12\nConstrua um objeto do tipo DataFrame com a estrutura abaixo e armazene em uma variável. \nColoque os dados em um dicionário Python.\n    A  B    C\n0  11  1  130\n1  33  2  144\n2  11  3  111\n3  -1  4  104\n4   0  5  199\n'

# %%
dic = {
    'A': [11, 33, 11, -1, 0],
    'B': [1, 2, 3, 4, 5],
    'C': [130, 144, 111, 104, 199]
}
df = pd.DataFrame(dic)
df
# Out:
#     A  B    C
# 0  11  1  130
# 1  33  2  144
# 2  11  3  111
# 3  -1  4  104
# 4   0  5  199

# %%
'''
Exercício 13
Construa um objeto do tipo DataFrame com a estrutura abaixo e armazene em uma variável. 
Observe que a coluna A corresponde a todos os números pares entre [1,20] e a coluna B ao cubo de cada número ímpar neste mesmo intervalo.

Coloque os dados em um dicionário Python e use Compreensão em Listas para construir as colunas.
    A     B
1    2     1
2    4    27
3    6   125
4    8   343
5   10   729
6   12  1331
7   14  2197
8   16  3375
9   18  4913
10  20  6859
'''
# Out:
# '\nExercício 13\nConstrua um objeto do tipo DataFrame com a estrutura abaixo e armazene em uma variável. \nObserve que a coluna A corresponde a todos os números pares entre [1,20] e a coluna B ao cubo de cada número ímpar neste mesmo intervalo.\n\nColoque os dados em um dicionário Python e use Compreensão em Listas para construir as colunas.\n    A     B\n1    2     1\n2    4    27\n3    6   125\n4    8   343\n5   10   729\n6   12  1331\n7   14  2197\n8   16  3375\n9   18  4913\n10  20  6859\n'

# %%
dic = {
    'A': [i for i in range(1,21) if i%2==0],
    'B': [i**3 for i in range(1,21) if i%2!=0]
}
df = pd.DataFrame(dic)
df
# Out:
#     A     B
# 0   2     1
# 1   4    27
# 2   6   125
# 3   8   343
# 4  10   729
# 5  12  1331
# 6  14  2197
# 7  16  3375
# 8  18  4913
# 9  20  6859

# %%
#ou
df = pd.DataFrame(dic, index=range(1, len(dic['A'])+1))
df
# Out:
#      A     B
# 1    2     1
# 2    4    27
# 3    6   125
# 4    8   343
# 5   10   729
# 6   12  1331
# 7   14  2197
# 8   16  3375
# 9   18  4913
# 10  20  6859

# %%
'''
Exercício 14
Para o DataFrame anterior plot um gráfico de linhas e adicione uma nova coluna 
com o quadrado de cada número ímpar no intervalo [1,20].
Para tanto use: df.plot().
'''
# Out:
# '\nExercício 14\nPara o DataFrame anterior plot um gráfico de linhas e adicione uma nova coluna \ncom o quadrado de cada número ímpar no intervalo [1,20].\nPara tanto use: df.plot().\n'

# %%
dic = {
    'A': [i for i in range(1,21) if i%2==0],
    'B': [i**3 for i in range(1,21) if i%2!=0],
}
df = pd.DataFrame(dic)
df['C'] = [i**2 for i in range(1,21) if i%2!=0]
df.plot();

# %%
'''
Exercício 15
Construa o DataFrame abaixo que representa os preços registrados por quatro produtos entre 2010 a 2019, 
gere uma visualização com o método visto anteriormente. Utilize o NumPy para gerar os preços (números aleatórios), 
de acordo com uma distribuição normal de média 800 e desvio padrão 30, para as respectivas colunas. 
Para tanto, use a função np.random.normal().
'''
# Out:
# '\nExercício 15\nConstrua o DataFrame abaixo que representa os preços registrados por quatro produtos entre 2010 a 2019, \ngere uma visualização com o método visto anteriormente. Utilize o NumPy para gerar os preços (números aleatórios), \nde acordo com uma distribuição normal de média 800 e desvio padrão 30, para as respectivas colunas. \nPara tanto, use a função np.random.normal().\n'

# %%
import numpy as np
valores = np.random.normal(800, 30, size=(10, 4)).round(2)
colunas = ['A', 'B', 'C', 'D']
anos = range(2010, 2020)
df = pd.DataFrame(valores, index = anos, columns = colunas)
df.columns.name = 'Produtos'
df.index.name = 'Anos'
df.plot();

# %%
'''
Exercício 16
Construa um objeto do tipo DataFrame com a estrutura abaixo, que represente uma tabela de preço, 
quantidade e custo total para um conjunto de produtos.

            Preço  Quantidade  Custo Total
Produto 1   20.3        10         100.00
Produto 2   31.2        33         568.70
Produto 3   44.7        45         205.20
Produto 4   30.5        51         507.10
Produto 5   19.8        11         250.12
Produto 6   11.2        8           55.30
Produto 7   15.7        91        1579.00
Produto 8   17.3        8          130.00
'''
# Out:
# '\nExercício 16\nConstrua um objeto do tipo DataFrame com a estrutura abaixo, que represente uma tabela de preço, \nquantidade e custo total para um conjunto de produtos.\n\n            Preço  Quantidade  Custo Total\nProduto 1   20.3        10         100.00\nProduto 2   31.2        33         568.70\nProduto 3   44.7        45         205.20\nProduto 4   30.5        51         507.10\nProduto 5   19.8        11         250.12\nProduto 6   11.2        8           55.30\nProduto 7   15.7        91        1579.00\nProduto 8   17.3        8          130.00\n'

# %%
dic = {
    'Preço': [20.3, 31.2, 44.7, 30.5, 19.8, 11.2, 15.7, 17.3],
    'Quantidade': [10, 33, 45, 51, 11, 8, 91, 8],
    'Custo total': [100.00, 568.70, 205.20, 507.10, 250.12, 55.30, 1579.00, 130.00]
}
index = ['Produto '+str(i) for i in range(1,9)]

df = pd.DataFrame(data = dic, index = index)
df
# Out:
#            Preço  Quantidade  Custo total
# Produto 1   20.3          10       100.00
# Produto 2   31.2          33       568.70
# Produto 3   44.7          45       205.20
# Produto 4   30.5          51       507.10
# Produto 5   19.8          11       250.12
# Produto 6   11.2           8        55.30
# Produto 7   15.7          91      1579.00
# Produto 8   17.3           8       130.00

# %%
'''
Exercício 17
Considerando o exercício anterior: (1) adicione uma nova coluna 'Receita Total' (RT) ao DataFrame,
 que corresponde ao produto entre o preço (p) e a quantidade (q), ou seja, RT = p x q; (2) 
 adicione uma nova coluna 'Lucro Total' (LT), 
 que corresponde a diferença entre a Receita Total e o Custo Total (CT), isto é, LT = RT - CT.

Resultado esperado:

Receita total     Lucro total
  203.00            103.00
 1029.6             460.90
 2011.5            1806.30
 1555.5            1048.40
  217.8             -32.32
   89.6              34.30
 1428.7            -150.30
  138.4               8.40
'''
# Out:
# "\nExercício 17\nConsiderando o exercício anterior: (1) adicione uma nova coluna 'Receita Total' (RT) ao DataFrame,\n que corresponde ao produto entre o preço (p) e a quantidade (q), ou seja, RT = p x q; (2) \n adicione uma nova coluna 'Lucro Total' (LT), \n que corresponde a diferença entre a Receita Total e o Custo Total (CT), isto é, LT = RT - CT.\n\nResultado esperado:\n\nReceita total     Lucro total\n  203.00            103.00\n 1029.6             460.90\n 2011.5            1806.30\n 1555.5            1048.40\n  217.8             -32.32\n   89.6              34.30\n 1428.7            -150.30\n  138.4               8.40\n"

# %%
dic = {
    'Preço': [20.3, 31.2, 44.7, 30.5, 19.8, 11.2, 15.7, 17.3],
    'Quantidade': [10, 33, 45, 51, 11, 8, 91, 8],
    'Custo total': [100.00, 568.70, 205.20, 507.10, 250.12, 55.30, 1579.00, 130.00]
}
index = ['Produto '+str(i) for i in range(1,9)]

df = pd.DataFrame(data = dic, index = index)
df['Receita Total'] = df['Preço']*df['Quantidade']
df['Lucro Total'] = df['Receita Total'] - df['Custo total']

df.head(8)
# Out:
#            Preço  Quantidade  Custo total  Receita Total  Lucro Total
# Produto 1   20.3          10       100.00          203.0       103.00
# Produto 2   31.2          33       568.70         1029.6       460.90
# Produto 3   44.7          45       205.20         2011.5      1806.30
# Produto 4   30.5          51       507.10         1555.5      1048.40
# Produto 5   19.8          11       250.12          217.8       -32.32
# Produto 6   11.2           8        55.30           89.6        34.30
# Produto 7   15.7          91      1579.00         1428.7      -150.30
# Produto 8   17.3           8       130.00          138.4         8.40

# %%
'''
Exercício 18
Construa um objeto do tipo DataFrame com a estrutura abaixo. Utilize np.random.random() para gerar números aleatórios.
'''
# Out:
# '\nExercício 18\nConstrua um objeto do tipo DataFrame com a estrutura abaixo. Utilize np.random.random() para gerar números aleatórios.\n'

# %%
import numpy as np
array = np.random.random(50).reshape((10, 5))
colunas = ['A', 'B', 'C', 'D', 'E']
df = pd.DataFrame(array, columns = colunas, index = range(1,11))
df
# Out:
#            A         B         C         D         E
# 1   0.767709  0.526094  0.633902  0.233872  0.070069
# 2   0.008408  0.238185  0.792983  0.409392  0.829194
# 3   0.296859  0.786343  0.621048  0.252476  0.631970
# 4   0.333211  0.073894  0.001172  0.405522  0.718384
# 5   0.626463  0.514377  0.677986  0.001460  0.931831
# 6   0.962642  0.192576  0.075322  0.516741  0.636848
# 7   0.613007  0.625531  0.324828  0.680376  0.269256
# 8   0.946887  0.134698  0.553666  0.701953  0.618197
# 9   0.878927  0.937770  0.223248  0.265910  0.807145
# 10  0.355906  0.874786  0.658470  0.945665  0.259563

# %%
# ou
import numpy as np
df = pd.DataFrame(np.random.random(50).reshape((10,5)),
                index = range(1,11),
                columns = list('ABCDE'))

df
# Out:
#            A         B         C         D         E
# 1   0.774734  0.276403  0.519644  0.085767  0.762538
# 2   0.906051  0.911201  0.009226  0.603471  0.429464
# 3   0.806865  0.768313  0.904983  0.868596  0.835792
# 4   0.355856  0.560514  0.845153  0.851147  0.015899
# 5   0.309914  0.003052  0.337980  0.270148  0.101547
# 6   0.516884  0.376479  0.818481  0.241483  0.805413
# 7   0.906806  0.898646  0.316300  0.337483  0.269510
# 8   0.712868  0.942944  0.513948  0.826650  0.321785
# 9   0.762637  0.112486  0.266974  0.291517  0.099881
# 10  0.948536  0.360781  0.508495  0.734575  0.554704

# %%
'''
Exercício 19
Use uma estrutura de dados com nested dict (dicionário aninhado) para criar o DataFrame a seguir.

Produtos      Produtos1     Produtos2     Produtos3     Produtos4
   Ano          
  2008          7             14             5            4         
  2009          9             13            11            2
  2010         10              7             3            3
  2011         15             13            45           45
  2012         50             77            21           21
  2013         47             94            33           33
'''
# Out:
# '\nExercício 19\nUse uma estrutura de dados com nested dict (dicionário aninhado) para criar o DataFrame a seguir.\n\nProdutos      Produtos1     Produtos2     Produtos3     Produtos4\n   Ano          \n  2008          7             14             5            4         \n  2009          9             13            11            2\n  2010         10              7             3            3\n  2011         15             13            45           45\n  2012         50             77            21           21\n  2013         47             94            33           33\n'

# %%
produtos = {
    'Produto1': {2008:7, 2009:9, 2010:10, 2011:15, 2012:50, 2013:47},
    'Produto2': {2008:14, 2009:13, 2010:7, 2011:13, 2012:77, 2013:94},
    'Produto3': {2008:5, 2009:11, 2010:3, 2011:45, 2012:21, 2013:33},
    'Produto4': {2008:4, 2009:2, 2010:3, 2011:45, 2012:21, 2013:33}
}
df = pd.DataFrame(produtos)
df.columns.name = 'Produtos'
df.index.name = 'Ano'

df
# Out:
# Produtos  Produto1  Produto2  Produto3  Produto4
# Ano
# 2008             7        14         5         4
# 2009             9        13        11         2
# 2010            10         7         3         3
# 2011            15        13        45        45
# 2012            50        77        21        21
# 2013            47        94        33        33

# %%
'''
Exercício 20
Construa o DataFrame abaixo e faça as seguintes operações:

dados = {
    'Cliente': ['Jéssica', 'Carlos', 'Rafael', 'João', 'Pedro', 'Júnior', 'Laís', 'Tales'],
    'Idade': [36, 39, 33, 32, 27, 35, 28, 18],
    'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66] 
}


a) Leia as 5 primeiras linhas com o método df.head();

b) Leia as 3 primeiras linhas com o método df.head(n = 10);

c) Leia as últimas 5 linhas com o método df.tail();

d) Leia as últimas 2 linhas com o método df.tail(n = 2).


'''
# Out:
# "\nExercício 20\nConstrua o DataFrame abaixo e faça as seguintes operações:\n\ndados = {\n    'Cliente': ['Jéssica', 'Carlos', 'Rafael', 'João', 'Pedro', 'Júnior', 'Laís', 'Tales'],\n    'Idade': [36, 39, 33, 32, 27, 35, 28, 18],\n    'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66] \n}\n\n\na) Leia as 5 primeiras linhas com o método df.head();\n\nb) Leia as 3 primeiras linhas com o método df.head(n = 10);\n\nc) Leia as últimas 5 linhas com o método df.tail();\n\nd) Leia as últimas 2 linhas com o método df.tail(n = 2).\n\n\n"

# %%
dados = {
    'Cliente': ['Jéssica', 'Carlos', 'Rafael', 'João', 'Pedro', 'Júnior', 'Laís', 'Tales'],
    'Idade': [36, 39, 33, 32, 27, 35, 28, 18],
    'Rating': [6.2, 2.17, 6.56, 8.32, 9.15, 1.34, 0.57, 1.66] 
}
df = pd.DataFrame(dados)
df
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56
# 3     João     32    8.32
# 4    Pedro     27    9.15
# 5   Júnior     35    1.34
# 6     Laís     28    0.57
# 7    Tales     18    1.66

# %%
A = df.head()
A
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56
# 3     João     32    8.32
# 4    Pedro     27    9.15

# %%
B = df.head(n = 3)
B
# Out:
#    Cliente  Idade  Rating
# 0  Jéssica     36    6.20
# 1   Carlos     39    2.17
# 2   Rafael     33    6.56

# %%
C = df.tail()
C
# Out:
#   Cliente  Idade  Rating
# 3    João     32    8.32
# 4   Pedro     27    9.15
# 5  Júnior     35    1.34
# 6    Laís     28    0.57
# 7   Tales     18    1.66

# %%
D = df.tail(n = 2)
D
# Out:
#   Cliente  Idade  Rating
# 6    Laís     28    0.57
# 7   Tales     18    1.66

# %%
'''
Exercício 21
Construa o DataFrame abaixo. Use Compreensão em Listas para criar a coluna 
'Resultado Final' (Dica: se Nota>=7 'Sim'). 
Utilize a função info() para mostrar informações do dataset.

nomes = ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales']
notas = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]

'''
# Out:
# "\nExercício 21\nConstrua o DataFrame abaixo. Use Compreensão em Listas para criar a coluna \n'Resultado Final' (Dica: se Nota>=7 'Sim'). \nUtilize a função info() para mostrar informações do dataset.\n\nnomes = ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales']\nnotas = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]\n\n"

# %%
nomes = ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales']
notas = [7, 8 , 4.7, 10, 9.5, 6, 5, 7.7]
aprovado = ['Sim' if nota>=7 else 'Não' for nota in notas]
dados = {
    'Nome': nomes,
    'Nota': notas,
    'Resultado Final': aprovado 
}
df = pd.DataFrame(dados)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nome             8 non-null      object
#  1   Nota             8 non-null      float64
#  2   Resultado Final  8 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 320.0+ bytes

# %%
'''
Exercício 22
Com base no exercício anterior:

a) aplice o método describe() para obter estatísticas descritivas das colunas numéricas;

b) imprima o aluno que tirou nota máxima;

c) imprima o aluno que tirou nota mínima;

d) selecione apenas os alunos aprovados e armazene em uma variável.
'''
# Out:
# '\nExercício 22\nCom base no exercício anterior:\n\na) aplice o método describe() para obter estatísticas descritivas das colunas numéricas;\n\nb) imprima o aluno que tirou nota máxima;\n\nc) imprima o aluno que tirou nota mínima;\n\nd) selecione apenas os alunos aprovados e armazene em uma variável.\n'

# %%
df
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 2  Rogério   4.7             Não
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não
# 6   Milena   5.0             Não
# 7    Tales   7.7             Sim

# %%
 A = df.describe()
 A
# Out:
#            Nota
# count   8.00000
# mean    7.23750
# std     1.94858
# min     4.70000
# 25%     5.75000
# 50%     7.35000
# 75%     8.37500
# max    10.00000

# %%
B = df['Nota'].max()
B
# Out:
# 10.0

# %%
C = df['Nota'].min()
C
# Out:
# 4.7

# %%
D = df[df['Resultado Final'] == 'Sim']
D
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 7    Tales   7.7             Sim

# %%
'''
Exercício 23
Com base no DataFrame abaixo,
import pandas as pd
import numpy as np
 
dados = np.random.uniform(low = 0, high = 5, size = (100,5))
df = pd.DataFrame(dados, 
                  index = range(1,dados.shape[0]+1), 
                  columns = list('ABCDE'))
 

Mostre na tela as seguintes informações:   

a) números de linhas;

b) número de colunas;

c) shape;

d) número total de elementos;

e) Número de dimensões;

f) informações do dataset com a função info();

g) o dtype de cada coluna;

h) estatísticas descritivas de cada coluna.
'''
# Out:
# "\nExercício 23\nCom base no DataFrame abaixo,\nimport pandas as pd\nimport numpy as np\n \ndados = np.random.uniform(low = 0, high = 5, size = (100,5))\ndf = pd.DataFrame(dados, \n                  index = range(1,dados.shape[0]+1), \n                  columns = list('ABCDE'))\n \n\nMostre na tela as seguintes informações:   \n\na) números de linhas;\n\nb) número de colunas;\n\nc) shape;\n\nd) número total de elementos;\n\ne) Número de dimensões;\n\nf) informações do dataset com a função info();\n\ng) o dtype de cada coluna;\n\nh) estatísticas descritivas de cada coluna.\n"

# %%
import numpy as np
 
dados = np.random.uniform(low = 0, high = 5, size = (100,5))
df = pd.DataFrame(dados, 
                  index = range(1,dados.shape[0]+1), 
                  columns = list('ABCDE'))

# %%
A = df.shape[0]
A
# Out:
# 100

# %%
B = df.shape[1]
B
# Out:
# 5

# %%
C = df.shape
C
# Out:
# (100, 5)

# %%
D = df.size
D
# Out:
# 500

# %%
E = df.ndim
E
# Out:
# 2

# %%
F = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    float64
#  2   C       100 non-null    float64
#  3   D       100 non-null    float64
#  4   E       100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
G = df.dtypes
G
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# dtype: object

# %%
H = df.describe()
H
# Out:
#                 A           B           C           D           E
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     2.398252    2.334121    2.494988    2.701001    2.426455
# std      1.476023    1.467460    1.506365    1.433192    1.430607
# min      0.020247    0.006885    0.112810    0.026955    0.036295
# 25%      1.067603    1.104581    1.119838    1.564641    1.103441
# 50%      2.438494    2.150018    2.609032    2.695809    2.191255
# 75%      3.568021    3.452414    3.906386    4.036242    3.802279
# max      4.974868    4.970194    4.938339    4.996392    4.884102

# %%
'''
Exercício 24
Construa o DataFrame abaixo e faça:

a) exiba o tipo de dados de cada coluna;

b) converta o dtype das colunas 'C' e 'E' para category (Dica: df['columns'].astype('category'));

c) selecione e imprima apenas as colunas do tipo category (Dica: df.select_dtypes('category'));

d) selecione e imprima apenas as colunas do tipo bool;

f) selecione e imprima apenas as colunas numéricas;

g) imprima estatísticas descritivas de cada coluna, incluindo as colunas categóricas.



dic = {
    'A': [11, 3, 7, 99, 100, 130, 150],
    'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],
    'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],
    'D': [True, False, True, False, True, False, True],    
    'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],
    'F': [True, True, False, False, True, False, True],}
'''
# Out:
# "\nExercício 24\nConstrua o DataFrame abaixo e faça:\n\na) exiba o tipo de dados de cada coluna;\n\nb) converta o dtype das colunas 'C' e 'E' para category (Dica: df['columns'].astype('category'));\n\nc) selecione e imprima apenas as colunas do tipo category (Dica: df.select_dtypes('category'));\n\nd) selecione e imprima apenas as colunas do tipo bool;\n\nf) selecione e imprima apenas as colunas numéricas;\n\ng) imprima estatísticas descritivas de cada coluna, incluindo as colunas categóricas.\n\n\n\ndic = {\n    'A': [11, 3, 7, 99, 100, 130, 150],\n    'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],\n    'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],\n    'D': [True, False, True, False, True, False, True],    \n    'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],\n    'F': [True, True, False, False, True, False, True],}\n"

# %%
dic = {
    'A': [11, 3, 7, 99, 100, 130, 150],
    'B': [1.2, 0.5, 1.2, 3.2, 0.9, 1.7, 9.5],
    'C': ['A', 'Z', 'W', 'K', 'A', 'Z', 'Z'],
    'D': [True, False, True, False, True, False, True],    
    'E': ['A', 'A', 'B', 'B', 'A', 'A', 'B'],
    'F': [True, True, False, False, True, False, True],}

index = list(range(10, 71, 10))
df = pd.DataFrame(dic, columns = list('ABCDEF'), index = index)
df
# Out:
#       A    B  C      D  E      F
# 10   11  1.2  A   True  A   True
# 20    3  0.5  Z  False  A   True
# 30    7  1.2  W   True  B  False
# 40   99  3.2  K  False  B  False
# 50  100  0.9  A   True  A   True
# 60  130  1.7  Z  False  A  False
# 70  150  9.5  Z   True  B   True

# %%
A = df.dtypes
A
# Out:
# A      int64
# B    float64
# C     object
# D       bool
# E     object
# F       bool
# dtype: object

# %%
B = df[['C', 'D']].astype('category')
B.dtypes
# Out:
# C    category
# D    category
# dtype: object

# %%
C = df.select_dtypes('category')
C
# Out:
# Empty DataFrame
# Columns: []
# Index: [10, 20, 30, 40, 50, 60, 70]

# %%
D = df.select_dtypes(bool)
D
# Out:
#         D      F
# 10   True   True
# 20  False   True
# 30   True  False
# 40  False  False
# 50   True   True
# 60  False  False
# 70   True   True

# %%
E = df.select_dtypes(include = [float, int])
E
# Out:
#       A    B
# 10   11  1.2
# 20    3  0.5
# 30    7  1.2
# 40   99  3.2
# 50  100  0.9
# 60  130  1.7
# 70  150  9.5

# %%
print('Estatisticas descritivas'.center(80, ' '))
F = df.describe(include = 'all').T
F
# Out:
#                             Estatisticas descritivas
#   count unique   top freq       mean        std  min   25%   50%    75%    max
# A   7.0    NaN   NaN  NaN  71.428571  62.803549  3.0   9.0  99.0  115.0  150.0
# B   7.0    NaN   NaN  NaN        2.6   3.162278  0.5  1.05   1.2   2.45    9.5
# C     7      4     Z    3        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# D     7      2  True    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# E     7      2     A    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN
# F     7      2  True    4        NaN        NaN  NaN   NaN   NaN    NaN    NaN

# %%
'''
Construa o DataFrame abaixo. Use o NumPy para construir os dados das colunas, com a função np.random.normal(), 
considere uma distribuição com média 10 e desvio padrão 0.5. 
Utilize Compreensão em Listas para configurar os índices e as colunas.
'''
# Out:
# '\nConstrua o DataFrame abaixo. Use o NumPy para construir os dados das colunas, com a função np.random.normal(), \nconsidere uma distribuição com média 10 e desvio padrão 0.5. \nUtilize Compreensão em Listas para configurar os índices e as colunas.\n'

# %%
import numpy as np
array = np.random.normal(10, 0.5 , size=(10, 10)).round(1)
col = [chr(64+i) for i in range(1, array.shape[1]+1)]
index = [chr(64+i)+str(i) for i in range(1,array.shape[0]+1)]
df = pd.DataFrame(data = array, columns = col, index = index)
df
# Out:
#         A     B     C     D     E     F     G     H     I     J
# A1   10.4  10.1  10.0  10.1  10.8  10.0  10.3  10.7  10.5  10.9
# B2   10.5  11.3   9.6  10.0  10.5   9.8   9.5  10.6   9.8   9.5
# C3   10.3   9.3   9.6  10.6  10.3  10.0   9.9   9.3  10.2   9.9
# D4    9.7   9.9   9.9  10.1   9.5  10.0  10.6  10.5  10.3   9.1
# E5   10.6  10.2  10.0  10.5   9.9  10.0   9.4  10.6  10.1   9.7
# F6   10.3  11.1  10.4  10.2   9.4   9.8  10.4  10.3   9.8   9.7
# G7   10.3   9.8  10.9  10.8   9.9   9.3   9.5  10.2  10.1   9.6
# H8    8.8   9.6   9.1  10.4   9.1   9.4  10.3  10.6   9.4  10.5
# I9   10.0  10.0   9.7  10.2  10.5  10.9  10.0   9.7  10.3  10.7
# J10   9.7  10.4  10.6  10.9   9.6   9.9  10.7  10.2   9.6   9.6

# %%
'''
Com base no DataFrame a seguir obtenha:

a) selecione a coluna 'Nome' e armazene em uma variável;

b) selecione a coluna 'Resultado Final' e armazene em uma variável;

c) selecione e imprima as coluna 'Nome' e 'Resultado Final';

d) selecione a linha 6 do DataFrame;

e) selecione as linhas 3 a 5 do DataFrame.

'''
# Out:
# "\nCom base no DataFrame a seguir obtenha:\n\na) selecione a coluna 'Nome' e armazene em uma variável;\n\nb) selecione a coluna 'Resultado Final' e armazene em uma variável;\n\nc) selecione e imprima as coluna 'Nome' e 'Resultado Final';\n\nd) selecione a linha 6 do DataFrame;\n\ne) selecione as linhas 3 a 5 do DataFrame.\n\n"

# %%
dados = {
    'Nome': ['Carlos', 'Rafael', 'Rogério', 'Ana', 'Beatriz', 'Jorge', 'Milena', 'Tales'],
    'Nota': [7.0, 8.0, 4.7, 10.0, 9.5, 6.0, 5.0, 7.7],
    'Resultado Final': ['Sim' if nota>=7 else 'Não' for nota in notas]
}
df = pd.DataFrame(dados)
df
# Out:
#       Nome  Nota Resultado Final
# 0   Carlos   7.0             Sim
# 1   Rafael   8.0             Sim
# 2  Rogério   4.7             Não
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não
# 6   Milena   5.0             Não
# 7    Tales   7.7             Sim

# %%
A = df['Nome']
A
# Out:
# 0     Carlos
# 1     Rafael
# 2    Rogério
# 3        Ana
# 4    Beatriz
# 5      Jorge
# 6     Milena
# 7      Tales
# Name: Nome, dtype: object

# %%
B = df['Resultado Final']
B
# Out:
# 0    Sim
# 1    Sim
# 2    Não
# 3    Sim
# 4    Sim
# 5    Não
# 6    Não
# 7    Sim
# Name: Resultado Final, dtype: object

# %%
C = df[['Nome', 'Resultado Final']]
C
# Out:
#       Nome Resultado Final
# 0   Carlos             Sim
# 1   Rafael             Sim
# 2  Rogério             Não
# 3      Ana             Sim
# 4  Beatriz             Sim
# 5    Jorge             Não
# 6   Milena             Não
# 7    Tales             Sim

# %%
D = df.iloc[6:7]
D
# Out:
#      Nome  Nota Resultado Final
# 6  Milena   5.0             Não

# %%
E = df.iloc[3:6]
E
# Out:
#       Nome  Nota Resultado Final
# 3      Ana  10.0             Sim
# 4  Beatriz   9.5             Sim
# 5    Jorge   6.0             Não

# %%
'''
Exercício 27
Ainda com base no DataFrame do exercício anterior:

a) selecione os nomes 'Rafael', 'Rogério' e 'Ana' e armazene em uma lista;

b) selecione os nomes 'Carlos', 'Rogério' e 'Tales' e armazene em uma lista;

c) selecione o nome 'Carlos';

d) selecione a nota 7.7.
'''
# Out:
# "\nExercício 27\nAinda com base no DataFrame do exercício anterior:\n\na) selecione os nomes 'Rafael', 'Rogério' e 'Ana' e armazene em uma lista;\n\nb) selecione os nomes 'Carlos', 'Rogério' e 'Tales' e armazene em uma lista;\n\nc) selecione o nome 'Carlos';\n\nd) selecione a nota 7.7.\n"

# %%
A = df.Nome[1:4].tolist()
A
# Out:
# ['Rafael', 'Rogério', 'Ana']

# %%
B = df.Nome.loc[[0,2,7]].tolist()
B
# Out:
# ['Carlos', 'Rogério', 'Tales']

# %%
C = df.Nome.iloc[0:1][0]
C
# Out:
# 'Carlos'

# %%
D = df.Nota.iloc[-1]
D
# Out:
# 7.7

# %%
'''
Crie o DataFrame abaixo, que representa o lucro de distintas marcas em anos de atuação de uma empresa. 
Use Compreensão em Listas para construir as colunas e os índices. Para constuir os valores use np.random.seed(7), 
de modo que os valores aleatórios sejam iguais aos definidos aqui neste exercício.

a) acesse os seguintes atributos: columns, index, shape e values;

b) selecione as colunas 'Marca A' e 'Marca C', individualmente;

c) mostre as estatísticas descritivas de cada coluna com a função describe();

d) mostre informações do dataset com a função info();

e) mostre o tipo de dado de cada coluna do dataset;

f) converta o data type das colunas para float;

g) selecione o lucro das marcas no ano 1 (use as funções loc e iloc);

h) selecione o lucro da Marca C nos anos 1 e 3 (use as funções loc e iloc);

i) selecione o lucro das marcas A, C e D, nos anos 2 e 4 (use as funções loc e iloc);

j) mostre o lucro médio de cada marca neste intervalo temporal;

k) mostre o lucro médio de todas as marcas em cada ano.
'''
# Out:
# "\nCrie o DataFrame abaixo, que representa o lucro de distintas marcas em anos de atuação de uma empresa. \nUse Compreensão em Listas para construir as colunas e os índices. Para constuir os valores use np.random.seed(7), \nde modo que os valores aleatórios sejam iguais aos definidos aqui neste exercício.\n\na) acesse os seguintes atributos: columns, index, shape e values;\n\nb) selecione as colunas 'Marca A' e 'Marca C', individualmente;\n\nc) mostre as estatísticas descritivas de cada coluna com a função describe();\n\nd) mostre informações do dataset com a função info();\n\ne) mostre o tipo de dado de cada coluna do dataset;\n\nf) converta o data type das colunas para float;\n\ng) selecione o lucro das marcas no ano 1 (use as funções loc e iloc);\n\nh) selecione o lucro da Marca C nos anos 1 e 3 (use as funções loc e iloc);\n\ni) selecione o lucro das marcas A, C e D, nos anos 2 e 4 (use as funções loc e iloc);\n\nj) mostre o lucro médio de cada marca neste intervalo temporal;\n\nk) mostre o lucro médio de todas as marcas em cada ano.\n"

# %%
import numpy as np
np.random.seed(7)

dados = np.random.randint(1,50,16,).reshape((4,4))
index = ['Ano '+str(i) for i in range(1,5)]
col = ['Marca '+chr(65+i) for i in range(4)]
df = pd.DataFrame(dados, columns = col, index= index )
df
# Out:
#        Marca A  Marca B  Marca C  Marca D
# Ano 1       48        5       26        4
# Ano 2       20       24       40       29
# Ano 3       15       24        9       26
# Ano 4       47       43       27        9

# %%
print(df.columns)
print(df.index)
print(df.shape)
print(df.values)
# Out:
# Index(['Marca A', 'Marca B', 'Marca C', 'Marca D'], dtype='object')
# Index(['Ano 1', 'Ano 2', 'Ano 3', 'Ano 4'], dtype='object')
# (4, 4)
# [[48  5 26  4]
#  [20 24 40 29]
#  [15 24  9 26]
#  [47 43 27  9]]

# %%
B = df['Marca A']
B
# Out:
# Ano 1    48
# Ano 2    20
# Ano 3    15
# Ano 4    47
# Name: Marca A, dtype: int64

# %%
B = df['Marca C']
B
# Out:
# Ano 1    26
# Ano 2    40
# Ano 3     9
# Ano 4    27
# Name: Marca C, dtype: int64

# %%
C = df.describe()
C
# Out:
#          Marca A    Marca B    Marca C    Marca D
# count   4.000000   4.000000   4.000000   4.000000
# mean   32.500000  24.000000  25.500000  17.000000
# std    17.445152  15.513435  12.714821  12.355835
# min    15.000000   5.000000   9.000000   4.000000
# 25%    18.750000  19.250000  21.750000   7.750000
# 50%    33.500000  24.000000  26.500000  17.500000
# 75%    47.250000  28.750000  30.250000  26.750000
# max    48.000000  43.000000  40.000000  29.000000

# %%
D = df.info()
D
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Ano 1 to Ano 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Marca A  4 non-null      int64
#  1   Marca B  4 non-null      int64
#  2   Marca C  4 non-null      int64
#  3   Marca D  4 non-null      int64
# dtypes: int64(4)
# memory usage: 332.0+ bytes

# %%
E = df.dtypes
E
# Out:
# Marca A    int64
# Marca B    int64
# Marca C    int64
# Marca D    int64
# dtype: object

# %%
F = df.astype(float)
F
# Out:
#        Marca A  Marca B  Marca C  Marca D
# Ano 1     48.0      5.0     26.0      4.0
# Ano 2     20.0     24.0     40.0     29.0
# Ano 3     15.0     24.0      9.0     26.0
# Ano 4     47.0     43.0     27.0      9.0

# %%
G = df.loc['Ano 1']
G
# Out:
# Marca A    48
# Marca B     5
# Marca C    26
# Marca D     4
# Name: Ano 1, dtype: int64

# %%
G = df.iloc[0:1, :]
G
# Out:
#        Marca A  Marca B  Marca C  Marca D
# Ano 1       48        5       26        4

# %%
H = df.loc[['Ano 1', 'Ano 3'], 'Marca C']
H
# Out:
# Ano 1    26
# Ano 3     9
# Name: Marca C, dtype: int64

# %%
H = df.iloc[[0, 2], 2:3]
H
# Out:
#        Marca C
# Ano 1       26
# Ano 3        9

# %%
I = df.loc[['Ano 2', 'Ano 4'], ['Marca A', 'Marca C', 'Marca D']]
I
# Out:
#        Marca A  Marca C  Marca D
# Ano 2       20       40       29
# Ano 4       47       27        9

# %%
I = df.iloc[[1, 3], [0, 2, 3]]
I
# Out:
#        Marca A  Marca C  Marca D
# Ano 2       20       40       29
# Ano 4       47       27        9

# %%
J = df.mean()
J
# Out:
# Marca A    32.5
# Marca B    24.0
# Marca C    25.5
# Marca D    17.0
# dtype: float64

# %%
K = df.mean(axis = 1)
K
# Out:
# Ano 1    20.75
# Ano 2    28.25
# Ano 3    18.50
# Ano 4    31.50
# dtype: float64

# %%
'''
Exercício 29
Com base no dataset anterior:

a) crie uma coluna para a 'Marca E', que registrou os seguintes lucros para os respectivos anos: 70, 77, 81, 103;

b) renomeie o nome das colunas para, respectivamente: 'A', 'B','C', 'D', 'E';

c) renomeie o índice do DataFrame para respectivamente: 'ANO 1', 'ANO 2', 'ANO 3', 'ANO 4';

d) substitua o valor do lucro da 'Marca C' ('C' na nova notação) no ANO 2 de 40 para 37.
'''
# Out:
# "\nExercício 29\nCom base no dataset anterior:\n\na) crie uma coluna para a 'Marca E', que registrou os seguintes lucros para os respectivos anos: 70, 77, 81, 103;\n\nb) renomeie o nome das colunas para, respectivamente: 'A', 'B','C', 'D', 'E';\n\nc) renomeie o índice do DataFrame para respectivamente: 'ANO 1', 'ANO 2', 'ANO 3', 'ANO 4';\n\nd) substitua o valor do lucro da 'Marca C' ('C' na nova notação) no ANO 2 de 40 para 37.\n"

# %%
#a) crie uma coluna para a 'Marca E', que registrou os seguintes lucros para os respectivos anos: 70, 77, 81, 103;
df['Marca E'] = [70, 77, 81, 103]

# %%
#b) renomeie o nome das colunas para, respectivamente: 'A', 'B','C', 'D', 'E';
df.rename(columns = {
    'Marca A': 'A',
    'Marca B': 'B',
    'Marca C': 'C',
    'Marca D': 'D',
    'Marca E': 'E'
}, inplace=True)
df.head()
# Out:
#         A   B   C   D    E
# Ano 1  48   5  26   4   70
# Ano 2  20  24  40  29   77
# Ano 3  15  24   9  26   81
# Ano 4  47  43  27   9  103

# %%
#c) renomeie o índice do DataFrame para respectivamente: 'ANO 1', 'ANO 2', 'ANO 3', 'ANO 4';
df.rename(index = lambda coluna: coluna.upper(), inplace=True)
df
# Out:
#         A   B   C   D    E
# ANO 1  48   5  26   4   70
# ANO 2  20  24  40  29   77
# ANO 3  15  24   9  26   81
# ANO 4  47  43  27   9  103

# %%
#d) substitua o valor do lucro da 'Marca C' ('C' na nova notação) no ANO 2 de 40 para 37.
df.at['ANO 2', 'C'] = 37
df
# Out:
#         A   B   C   D    E
# ANO 1  48   5  26   4   70
# ANO 2  20  24  37  29   77
# ANO 3  15  24   9  26   81
# ANO 4  47  43  27   9  103

# %%
'''
Exercício 30
Verifique se os valores do DataFrame estão contido na lista ['f', 'b', 'z']. Dica: df.isin().

dic = {
    'A': ['a', 'b', 'c'],
    'B': ['f', 'g', 'w'],
    'C': ['z', 'k', 'm']}
'''
# Out:
# "\nExercício 30\nVerifique se os valores do DataFrame estão contido na lista ['f', 'b', 'z']. Dica: df.isin().\n\ndic = {\n    'A': ['a', 'b', 'c'],\n    'B': ['f', 'g', 'w'],\n    'C': ['z', 'k', 'm']}\n"

# %%
dic = {
    'A': ['a', 'b', 'c'],
    'B': ['f', 'g', 'w'],
    'C': ['z', 'k', 'm']}

df = pd.DataFrame(dic)
df
# Out:
#    A  B  C
# 0  a  f  z
# 1  b  g  k
# 2  c  w  m

# %%
df.isin(['f', 'b', 'z'])
# Out:
#        A      B      C
# 0  False   True   True
# 1   True  False  False
# 2  False  False  False

# %%
'''
Delete as colunas 'B', 'Z' e 'W' do DataFrame abaixo.

data = {
    'A': ['z', 'k' ,'m'],
    'B': ['j', 'n' , 'o'],
    'C': ['o', 'p', 'k'],
    'Z': ['i', 'j' ,'k'],
    'W': ['p', 'k', 'u']
}
'''
# Out:
# "\nDelete as colunas 'B', 'Z' e 'W' do DataFrame abaixo.\n\ndata = {\n    'A': ['z', 'k' ,'m'],\n    'B': ['j', 'n' , 'o'],\n    'C': ['o', 'p', 'k'],\n    'Z': ['i', 'j' ,'k'],\n    'W': ['p', 'k', 'u']\n}\n"

# %%
data = {
    'A': ['z', 'k' ,'m'],
    'B': ['j', 'n' , 'o'],
    'C': ['o', 'p', 'k'],
    'Z': ['i', 'j' ,'k'],
    'W': ['p', 'k', 'u']
}
df = pd.DataFrame(data)

# %%
df.drop(labels = ['B', 'Z', 'W'], axis = 1, inplace = True)

# %%
df
# Out:
#    A  C
# 0  z  o
# 1  k  p
# 2  m  k

# %%
'''
Exercício 32
Construa o DataFrame abaixo e obtenha:


a) Estatística descritivas das notas;

b) crie uma nova coluna para armazenar a média final dos alunos;

c) crie uma nova coluna para informar se o aluno passou de ano ou não, com base na nota final 
(a nota deve ser maior ou igual a 7); para tanto crie uma função e use o método apply() do pandas.

alunos = [
    'Naomi', 'Yumi','Hinata',
    'Hana', 'Akira', 'Yuki',
    'Yudi', 'Sakura', 'Sasuke',
    'Hiroshi', 'Ken', 'Emi']
matematica = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]
quimica = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]
biologia = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]
economia = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]
'''
# Out:
# "\nExercício 32\nConstrua o DataFrame abaixo e obtenha:\n\n\na) Estatística descritivas das notas;\n\nb) crie uma nova coluna para armazenar a média final dos alunos;\n\nc) crie uma nova coluna para informar se o aluno passou de ano ou não, com base na nota final \n(a nota deve ser maior ou igual a 7); para tanto crie uma função e use o método apply() do pandas.\n\nalunos = [\n    'Naomi', 'Yumi','Hinata',\n    'Hana', 'Akira', 'Yuki',\n    'Yudi', 'Sakura', 'Sasuke',\n    'Hiroshi', 'Ken', 'Emi']\nmatematica = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]\nquimica = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]\nbiologia = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]\neconomia = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]\n"

# %%
alunos = [
    'Naomi', 'Yumi','Hinata',
    'Hana', 'Akira', 'Yuki',
    'Yudi', 'Sakura', 'Sasuke',
    'Hiroshi', 'Ken', 'Emi']
matematica = [1, 3, 1, 3, 4, 3, 1, 9, 5, 9, 1, 2]
quimica = [6, 5, 5, 8, 6, 6, 5, 3, 7, 8, 6, 4]
biologia = [8, 7, 9, 9, 7, 7, 8, 7, 7, 7, 7, 9]
economia = [3, 2, 7, 8, 9, 9, 5, 9, 8, 6, 7, 9]
dados = {
    'Alunos': alunos,
    'Matmática': matematica,
    'Quimica': quimica,
    'Biologia': biologia,
    'Economia': economia
}

df = pd.DataFrame(dados, index = range(1, len(alunos)+1))
df
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia
# 1     Naomi          1        6         8         3
# 2      Yumi          3        5         7         2
# 3    Hinata          1        5         9         7
# 4      Hana          3        8         9         8
# 5     Akira          4        6         7         9
# 6      Yuki          3        6         7         9
# 7      Yudi          1        5         8         5
# 8    Sakura          9        3         7         9
# 9    Sasuke          5        7         7         8
# 10  Hiroshi          9        8         7         6
# 11      Ken          1        6         7         7
# 12      Emi          2        4         9         9

# %%
A = df.describe()
A
# Out:
#        Matmática    Quimica   Biologia   Economia
# count  12.000000  12.000000  12.000000  12.000000
# mean    3.500000   5.750000   7.666667   6.833333
# std     2.876235   1.484771   0.887625   2.405801
# min     1.000000   3.000000   7.000000   2.000000
# 25%     1.000000   5.000000   7.000000   5.750000
# 50%     3.000000   6.000000   7.000000   7.500000
# 75%     4.250000   6.250000   8.250000   9.000000
# max     9.000000   8.000000   9.000000   9.000000

# %%
df['Média Final'] = df.drop(['Alunos'], axis = 1).mean(axis = 1)

# %%
def resultado(nota):
    if nota>=7:
        return 'Aprovado'
    else:
        return 'Reprovado'

df['Resultado'] = df['Média Final'].apply(resultado)

# %%
df
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1     Naomi          1        6         8         3         4.50  Reprovado
# 2      Yumi          3        5         7         2         4.25  Reprovado
# 3    Hinata          1        5         9         7         5.50  Reprovado
# 4      Hana          3        8         9         8         7.00   Aprovado
# 5     Akira          4        6         7         9         6.50  Reprovado
# 6      Yuki          3        6         7         9         6.25  Reprovado
# 7      Yudi          1        5         8         5         4.75  Reprovado
# 8    Sakura          9        3         7         9         7.00   Aprovado
# 9    Sasuke          5        7         7         8         6.75  Reprovado
# 10  Hiroshi          9        8         7         6         7.50   Aprovado
# 11      Ken          1        6         7         7         5.25  Reprovado
# 12      Emi          2        4         9         9         6.00  Reprovado

# %%
'''
Exercício 33
Com base no dataset anterior filtre:

a) os alunos que tiveram nota em Matemática maior ou igual a 7;

b) os alunos que tiveram nota em Química menor que 5;

c) os alunos que tiveram nota em Biologia igual a 8;

d) os alunos que tiveram nota em Economia diferente de 9;

e) os alunos que tiveram média final menor que 5;

f) os alunos aprovados.
'''
# Out:
# '\nExercício 33\nCom base no dataset anterior filtre:\n\na) os alunos que tiveram nota em Matemática maior ou igual a 7;\n\nb) os alunos que tiveram nota em Química menor que 5;\n\nc) os alunos que tiveram nota em Biologia igual a 8;\n\nd) os alunos que tiveram nota em Economia diferente de 9;\n\ne) os alunos que tiveram média final menor que 5;\n\nf) os alunos aprovados.\n'

# %%
#a) os alunos que tiveram nota em Matemática maior ou igual a 7;
A = df[df['Matmática'] >= 7]
A
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final Resultado
# 8    Sakura          9        3         7         9          7.0  Aprovado
# 10  Hiroshi          9        8         7         6          7.5  Aprovado

# %%
#b) os alunos que tiveram nota em Química menor que 5;
B = df[df['Quimica'] < 5]
B
# Out:
#     Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 8   Sakura          9        3         7         9          7.0   Aprovado
# 12     Emi          2        4         9         9          6.0  Reprovado

# %%
#c) os alunos que tiveram nota em Biologia igual a 8;
C = df[df['Biologia'] == 8]
C
# Out:
#   Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1  Naomi          1        6         8         3         4.50  Reprovado
# 7   Yudi          1        5         8         5         4.75  Reprovado

# %%
#d) os alunos que tiveram nota em Economia diferente de 9;
D = df[df['Economia'] != 9]
D
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1     Naomi          1        6         8         3         4.50  Reprovado
# 2      Yumi          3        5         7         2         4.25  Reprovado
# 3    Hinata          1        5         9         7         5.50  Reprovado
# 4      Hana          3        8         9         8         7.00   Aprovado
# 7      Yudi          1        5         8         5         4.75  Reprovado
# 9    Sasuke          5        7         7         8         6.75  Reprovado
# 10  Hiroshi          9        8         7         6         7.50   Aprovado
# 11      Ken          1        6         7         7         5.25  Reprovado

# %%
#e) os alunos que tiveram média final menor que 5;
E = df[df['Média Final'] < 5]
E
# Out:
#   Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1  Naomi          1        6         8         3         4.50  Reprovado
# 2   Yumi          3        5         7         2         4.25  Reprovado
# 7   Yudi          1        5         8         5         4.75  Reprovado

# %%
#f) os alunos aprovados.
F = df[df['Resultado'] == 'Aprovado']
F
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final Resultado
# 4      Hana          3        8         9         8          7.0  Aprovado
# 8    Sakura          9        3         7         9          7.0  Aprovado
# 10  Hiroshi          9        8         7         6          7.5  Aprovado

# %%
'''
Utilize a função query() para obter os filtros do exercício anterior.
'''
# Out:
# '\nUtilize a função query() para obter os filtros do exercício anterior.\n'

# %%
#a) os alunos que tiveram nota em Matemática maior ou igual a 7;
A = df.query('Matmática >= 7')
A
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final Resultado
# 8    Sakura          9        3         7         9          7.0  Aprovado
# 10  Hiroshi          9        8         7         6          7.5  Aprovado

# %%
#b) os alunos que tiveram nota em Química menor que 5;
B = df.query('Quimica < 5')
B
# Out:
#     Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 8   Sakura          9        3         7         9          7.0   Aprovado
# 12     Emi          2        4         9         9          6.0  Reprovado

# %%
#c) os alunos que tiveram nota em Biologia igual a 8;
C = df.query('Biologia == 8')
C
# Out:
#   Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1  Naomi          1        6         8         3         4.50  Reprovado
# 7   Yudi          1        5         8         5         4.75  Reprovado

# %%
#d) os alunos que tiveram nota em Economia diferente de 9;
D = df.query('Economia != 8')
D
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1     Naomi          1        6         8         3         4.50  Reprovado
# 2      Yumi          3        5         7         2         4.25  Reprovado
# 3    Hinata          1        5         9         7         5.50  Reprovado
# 5     Akira          4        6         7         9         6.50  Reprovado
# 6      Yuki          3        6         7         9         6.25  Reprovado
# 7      Yudi          1        5         8         5         4.75  Reprovado
# 8    Sakura          9        3         7         9         7.00   Aprovado
# 10  Hiroshi          9        8         7         6         7.50   Aprovado
# 11      Ken          1        6         7         7         5.25  Reprovado
# 12      Emi          2        4         9         9         6.00  Reprovado

# %%
#e) os alunos que tiveram média final menor que 5;
E = df.query('`Média Final` < 5')
E
# Out:
#   Alunos  Matmática  Quimica  Biologia  Economia  Média Final  Resultado
# 1  Naomi          1        6         8         3         4.50  Reprovado
# 2   Yumi          3        5         7         2         4.25  Reprovado
# 7   Yudi          1        5         8         5         4.75  Reprovado

# %%
#f) os alunos aprovados.
F = df.query("Resultado ==  'Aprovado'")
F
# Out:
#      Alunos  Matmática  Quimica  Biologia  Economia  Média Final Resultado
# 4      Hana          3        8         9         8          7.0  Aprovado
# 8    Sakura          9        3         7         9          7.0  Aprovado
# 10  Hiroshi          9        8         7         6          7.5  Aprovado

# %%
'''
Exercício 35
Construa o DataFrame a seguir usando Dicionários aninhados. Este exercício será utilizado a seguir.
'''
# Out:
# '\nExercício 35\nConstrua o DataFrame a seguir usando Dicionários aninhados. Este exercício será utilizado a seguir.\n'

# %%
dic = {
    'Empresa A': {2018:90, 2019:76, 2020:109},
    'Empresa B': {2018:33, 2020:13},
    'Empresa C': {2018:273, 2019:33}
}
df = pd.DataFrame(dic)

df.index.name = 'Ano'
df.columns.name = 'Faturamento'
df
# Out:
# Faturamento  Empresa A  Empresa B  Empresa C
# Ano
# 2018                90       33.0      273.0
# 2019                76        NaN       33.0
# 2020               109       13.0        NaN

# %%
'''
Exercício 36
Baseado no DataFrame anterior use a função pd.isna() para mapear os dados ausentes. 
Mostre ainda a quantidade de dados ausentes em cada coluna.
'''
# Out:
# '\nExercício 36\nBaseado no DataFrame anterior use a função pd.isna() para mapear os dados ausentes. \nMostre ainda a quantidade de dados ausentes em cada coluna.\n'

# %%
pd.isna(df)
# Out:
# Faturamento  Empresa A  Empresa B  Empresa C
# Ano
# 2018             False      False      False
# 2019             False       True      False
# 2020             False      False       True

# %%
pd.isna(df).sum()
# Out:
# Faturamento
# Empresa A    0
# Empresa B    1
# Empresa C    1
# dtype: int64

# %%
'''
Exercício 37
Com base no DataFrame do exercício 35, faça:

a) substitua os dados ausentes pela média no caso da Empresa B;

b) substitua os dados ausentes pela mediana no caso da Empresa C;

a) use idxmin()/idxmax() para filtrar os anos em que as respectivas empresas tiveram maior e menor lucro.
'''
# Out:
# '\nExercício 37\nCom base no DataFrame do exercício 35, faça:\n\na) substitua os dados ausentes pela média no caso da Empresa B;\n\nb) substitua os dados ausentes pela mediana no caso da Empresa C;\n\na) use idxmin()/idxmax() para filtrar os anos em que as respectivas empresas tiveram maior e menor lucro.\n'

# %%
#a) substitua os dados ausentes pela média no caso da Empresa B;
#b) substitua os dados ausentes pela mediana no caso da Empresa C;
df.fillna(
    {'Empresa B':df['Empresa B'].mean(), 'Empresa C': df['Empresa C'].median()}, inplace = True)

# %%
df
# Out:
# Faturamento  Empresa A  Empresa B  Empresa C
# Ano
# 2018                90       33.0      273.0
# 2019                76       23.0       33.0
# 2020               109       13.0      153.0

# %%
print('Ano de menor lucro'.center(50, ' '))
print(df.idxmin())
# Out:
#                 Ano de menor lucro
# Faturamento
# Empresa A    2019
# Empresa B    2020
# Empresa C    2019
# dtype: int64

# %%
print('Ano de Maior lucro'.center(50, ' '))
print(df.idxmax())
# Out:
#                 Ano de Maior lucro
# Faturamento
# Empresa A    2020
# Empresa B    2018
# Empresa C    2018
# dtype: int64

# %%
'''
Exercício 38
A Series a seguir representa o faturamento de uma empresa no tempo. Obtenha a linha com o maior e o menor faturamento, respectivamente.

2016-12-31    15
2017-12-31    31
2018-12-31    41
2019-12-31    47
2020-12-31    39
2021-12-31    10
2022-12-31    33
2023-12-31    13
2024-12-31    31
2025-12-31    33
Freq: A-DEC, dtype: int64
'''
# Out:
# '\nExercício 38\nA Series a seguir representa o faturamento de uma empresa no tempo. Obtenha a linha com o maior e o menor faturamento, respectivamente.\n\n2016-12-31    15\n2017-12-31    31\n2018-12-31    41\n2019-12-31    47\n2020-12-31    39\n2021-12-31    10\n2022-12-31    33\n2023-12-31    13\n2024-12-31    31\n2025-12-31    33\nFreq: A-DEC, dtype: int64\n'

# %%
s = pd.Series([15, 31, 41, 47, 39, 10, 33, 13, 31, 33],
              index = pd.date_range(start = '2016', periods = 10, freq = 'Y'))
s
# Out:
# 2016-12-31    15
# 2017-12-31    31
# 2018-12-31    41
# 2019-12-31    47
# 2020-12-31    39
# 2021-12-31    10
# 2022-12-31    33
# 2023-12-31    13
# 2024-12-31    31
# 2025-12-31    33
# Freq: A-DEC, dtype: int64

# %%
print('Ano com maior faturamento: ', s.idxmax().strftime('%Y'))
print('Ano com menor faturamento: ', s.idxmin().strftime('%Y'))
# Out:
# Ano com maior faturamento:  2019
# Ano com menor faturamento:  2021

# %%
'''
Exercício 39
A função drop() do pandas permite remover linhas ou colunas, 
retornando um novo objeto excluindo-se os itens especificados.
Remova as seguintes linhas do objeto Series abaixo: a) linha 'Year 1'; b) 
seguidamente as linhas 'Year 2' e 'Year 4'.
'''
# Out:
# "\nExercício 39\nA função drop() do pandas permite remover linhas ou colunas, \nretornando um novo objeto excluindo-se os itens especificados.\nRemova as seguintes linhas do objeto Series abaixo: a) linha 'Year 1'; b) \nseguidamente as linhas 'Year 2' e 'Year 4'.\n"

# %%
import numpy as np
series = pd.Series(np.random.randint(100, 150, 4), index = ['Year 1', 'Year 2', 'Year 3', 'Year 4'])
series
# Out:
# Year 1    139
# Year 2    138
# Year 3    104
# Year 4    148
# dtype: int64

# %%
series.drop(index = 'Year 1', inplace = True)
series.drop(index = ['Year 2', 'Year 4'], inplace = True)
series
# Out:
# Year 3    104
# dtype: int64

# %%
'''
Exercício 40
Com base no DataFrame abaixo, faça: a) delete as linha 'k' e 'j'; b) delete as colunas 'A' e 'D'.

Para construir os dados use:
import numpy as np
np.random.seed(77)
data = np.random.randint(1,50,16).reshape((4,4))
'''
# Out:
# "\nExercício 40\nCom base no DataFrame abaixo, faça: a) delete as linha 'k' e 'j'; b) delete as colunas 'A' e 'D'.\n\nPara construir os dados use:\nimport numpy as np\nnp.random.seed(77)\ndata = np.random.randint(1,50,16).reshape((4,4))\n"

# %%
import numpy as np
np.random.seed(77)
data = np.random.randint(1,50,16).reshape((4,4))
df = pd.DataFrame(data, index = list('ijkw'), columns = list('ABCD'))
df
# Out:
#     A   B   C   D
# i  24  32  21  21
# j  44  38  25  32
# k  33  40  45  20
# w  33  37  37  48

# %%
#deletando a linha k e J
df.drop(['k', 'j'], inplace = True)

# %%
#deletando as colunas A e D
df.drop(['A', 'D'], axis = 1, inplace = True)

# %%
df
# Out:
#     B   C
# i  32  21
# w  37  37

# %%
'''
Exercício 41
Use a função pd.date_range() para criar o índice do DataFrame a seguir 
(esta função permite gerar uma sequência de data - retornando um objeto DatetimeIndex, com diversas aplicações em análise de dados financeiros). 
Como argumentos da função especifique:

start = '2020-12-01'

periods = 31

freq = 'D'

Em seguida crie o DataFrame abaixo, sendo que os valores seguem uma distribuição normal 
com média 30, desvio padrão 0.5, com 31 elementos (Use a biblioteca NumPy). 
Gere uma visualização para os dados (Use a função df.plot()).
Use np.random.seed(21) para gerar números aleatórios iguais ao deste exercício.
'''
# Out:
# "\nExercício 41\nUse a função pd.date_range() para criar o índice do DataFrame a seguir \n(esta função permite gerar uma sequência de data - retornando um objeto DatetimeIndex, com diversas aplicações em análise de dados financeiros). \nComo argumentos da função especifique:\n\nstart = '2020-12-01'\n\nperiods = 31\n\nfreq = 'D'\n\nEm seguida crie o DataFrame abaixo, sendo que os valores seguem uma distribuição normal \ncom média 30, desvio padrão 0.5, com 31 elementos (Use a biblioteca NumPy). \nGere uma visualização para os dados (Use a função df.plot()).\nUse np.random.seed(21) para gerar números aleatórios iguais ao deste exercício.\n"

# %%
import numpy as np
np.random.seed(21)
frequencia = pd.date_range(start = '2020-12-01', periods = 31, freq = 'D')
valores = np.random.normal(30, 0.5, 31)
df = pd.DataFrame(data = valores, index = frequencia, columns = ['Série'])
df.head()
# Out:
#                 Série
# 2020-12-01  29.974018
# 2020-12-02  29.944402
# 2020-12-03  30.520898
# 2020-12-04  29.371630
# 2020-12-05  30.372694

# %%
df.plot(color = 'k');

# %%
'''
Exercício 42
Crie um date_range() com os meses de 2021 e armazene em uma variável. Mude o argumento freq para 'M'.
'''
# Out:
# "\nExercício 42\nCrie um date_range() com os meses de 2021 e armazene em uma variável. Mude o argumento freq para 'M'.\n"

# %%
frequencia = pd.date_range(start='1-1-2021', periods=12, freq='M')
frequencia
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
'''
Exercício 42
Crie um date_range() com os meses de 2021 e armazene em uma variável. Mude o argumento freq para 'M'.
'''
# Out:
# "\nExercício 42\nCrie um date_range() com os meses de 2021 e armazene em uma variável. Mude o argumento freq para 'M'.\n"

# %%
frequencia = pd.date_range(start='1-1-2010', end = '31-12-2040' , freq='A')
frequencia
# Out:
# DatetimeIndex(['2010-12-31', '2011-12-31', '2012-12-31', '2013-12-31',
#                '2014-12-31', '2015-12-31', '2016-12-31', '2017-12-31',
#                '2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31',
#                '2022-12-31', '2023-12-31', '2024-12-31', '2025-12-31',
#                '2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31',
#                '2030-12-31', '2031-12-31', '2032-12-31', '2033-12-31',
#                '2034-12-31', '2035-12-31', '2036-12-31', '2037-12-31',
#                '2038-12-31', '2039-12-31', '2040-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
'''
Exercício 44
Construa um DatetimeIndex para todos os dias do mês de setembro de 2021 (ano-mês-dia).
Seguidamente construa uma Series com o date_range criado.
'''
# Out:
# '\nExercício 44\nConstrua um DatetimeIndex para todos os dias do mês de setembro de 2021 (ano-mês-dia).\nSeguidamente construa uma Series com o date_range criado.\n'

# %%
frequencia = pd.date_range(start = '2021-9-1', periods = 29)
series = pd.Series(frequencia)
series
# Out:
# 0    2021-09-01
# 1    2021-09-02
# 2    2021-09-03
# 3    2021-09-04
# 4    2021-09-05
# 5    2021-09-06
# 6    2021-09-07
# 7    2021-09-08
# 8    2021-09-09
# 9    2021-09-10
# 10   2021-09-11
# 11   2021-09-12
# 12   2021-09-13
# 13   2021-09-14
# 14   2021-09-15
# 15   2021-09-16
# 16   2021-09-17
# 17   2021-09-18
# 18   2021-09-19
# 19   2021-09-20
# 20   2021-09-21
# 21   2021-09-22
# 22   2021-09-23
# 23   2021-09-24
# 24   2021-09-25
# 25   2021-09-26
# 26   2021-09-27
# 27   2021-09-28
# 28   2021-09-29
# dtype: datetime64[ns]

# %%
'''
Exercício 45
Construa um DatetimeIndex para todos os trimestres de 2021. Seguidamente construa uma Series com o date_range criado.
'''
# Out:
# '\nExercício 45\nConstrua um DatetimeIndex para todos os trimestres de 2021. Seguidamente construa uma Series com o date_range criado.\n'

# %%
frequencia = pd.date_range(start='1-1-2021', periods = 4, freq = '3M')
series = pd.Series(frequencia)
series
# Out:
# 0   2021-01-31
# 1   2021-04-30
# 2   2021-07-31
# 3   2021-10-31
# dtype: datetime64[ns]

# %%
'''
Exercício 46
Construa um date_range() para o dia 31 de dezembro de 2030, com intervalo de 1 hora.
'''
# Out:
# '\nExercício 46\nConstrua um date_range() para o dia 31 de dezembro de 2030, com intervalo de 1 hora.\n'

# %%
hora = pd.date_range(start='31-12-2030', periods=24, freq='H')
hora
# Out:
# DatetimeIndex(['2030-12-31 00:00:00', '2030-12-31 01:00:00',
#                '2030-12-31 02:00:00', '2030-12-31 03:00:00',
#                '2030-12-31 04:00:00', '2030-12-31 05:00:00',
#                '2030-12-31 06:00:00', '2030-12-31 07:00:00',
#                '2030-12-31 08:00:00', '2030-12-31 09:00:00',
#                '2030-12-31 10:00:00', '2030-12-31 11:00:00',
#                '2030-12-31 12:00:00', '2030-12-31 13:00:00',
#                '2030-12-31 14:00:00', '2030-12-31 15:00:00',
#                '2030-12-31 16:00:00', '2030-12-31 17:00:00',
#                '2030-12-31 18:00:00', '2030-12-31 19:00:00',
#                '2030-12-31 20:00:00', '2030-12-31 21:00:00',
#                '2030-12-31 22:00:00', '2030-12-31 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
'''
Exercício 48
Construa o date_range() com as quinzenas do primeiro semestre de 2021.
'''
# Out:
# '\nExercício 48\nConstrua o date_range() com as quinzenas do primeiro semestre de 2021.\n'

# %%
quinzena = pd.date_range(start = '1-1-2021', end = '30-6-2021', freq='15D')
quinzena
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-16', '2021-01-31', '2021-02-15',
#                '2021-03-02', '2021-03-17', '2021-04-01', '2021-04-16',
#                '2021-05-01', '2021-05-16', '2021-05-31', '2021-06-15',
#                '2021-06-30'],
#               dtype='datetime64[ns]', freq='15D')

# %%
'''
Exercício 49
Construa o DataFrame abaixo.



        Data  Dia do Ano  Mês do Ano
0  2021-01-01           1           1
1  2021-01-16          16           1
2  2021-01-31          31           1
3  2021-02-15          46           2
4  2021-03-02          61           3
5  2021-03-17          76           3
6  2021-04-01          91           4
7  2021-04-16         106           4
8  2021-05-01         121           5
9  2021-05-16         136           5
10 2021-05-31         151           5
11 2021-06-15         166           6
12 2021-06-30         181           6
13 2021-07-15         196           7
14 2021-07-30         211           7
15 2021-08-14         226           8
16 2021-08-29         241           8
17 2021-09-13         256           9
18 2021-09-28         271           9
19 2021-10-13         286          10
20 2021-10-28         301          10
21 2021-11-12         316          11
22 2021-11-27         331          11
23 2021-12-12         346          12
24 2021-12-27         361          12
'''
# Out:
# '\nExercício 49\nConstrua o DataFrame abaixo.\n\n\n\n        Data  Dia do Ano  Mês do Ano\n0  2021-01-01           1           1\n1  2021-01-16          16           1\n2  2021-01-31          31           1\n3  2021-02-15          46           2\n4  2021-03-02          61           3\n5  2021-03-17          76           3\n6  2021-04-01          91           4\n7  2021-04-16         106           4\n8  2021-05-01         121           5\n9  2021-05-16         136           5\n10 2021-05-31         151           5\n11 2021-06-15         166           6\n12 2021-06-30         181           6\n13 2021-07-15         196           7\n14 2021-07-30         211           7\n15 2021-08-14         226           8\n16 2021-08-29         241           8\n17 2021-09-13         256           9\n18 2021-09-28         271           9\n19 2021-10-13         286          10\n20 2021-10-28         301          10\n21 2021-11-12         316          11\n22 2021-11-27         331          11\n23 2021-12-12         346          12\n24 2021-12-27         361          12\n'

# %%
data = pd.date_range(start = '2021-1-1', end = '2021-12-31', freq = '15D')
df = pd.DataFrame(data, columns = ['Data'])
df['Dia do Ano'] = data.dayofyear
df['Mês do Ano'] = data.month
df.head()
# Out:
#         Data  Dia do Ano  Mês do Ano
# 0 2021-01-01           1           1
# 1 2021-01-16          16           1
# 2 2021-01-31          31           1
# 3 2021-02-15          46           2
# 4 2021-03-02          61           3

# %%
'''
Exercício 50
Construa o DataFrame abaixo, use o dicionário 'dados' e a função date_range() para construir o índice.
import numpy as np
n = 1096 #total de observações
dados = {
    'A': np.random.randint(low = 1, high = 1500, size = n),
    'B': np.random.normal(loc = 10, scale = 2, size = n),
    'C': np.random.uniform(low = 0, high = 1, size = n),
    'D': np.random.lognormal(mean = 4, sigma = 5, size = n),
    'E': np.random.standard_normal(size = n)}
Indice = inicio: 2018-01-01 final = 2021-12-31 pulando por mês

'''
# Out:
# "\nExercício 50\nConstrua o DataFrame abaixo, use o dicionário 'dados' e a função date_range() para construir o índice.\nimport numpy as np\nn = 1096 #total de observações\ndados = {\n    'A': np.random.randint(low = 1, high = 1500, size = n),\n    'B': np.random.normal(loc = 10, scale = 2, size = n),\n    'C': np.random.uniform(low = 0, high = 1, size = n),\n    'D': np.random.lognormal(mean = 4, sigma = 5, size = n),\n    'E': np.random.standard_normal(size = n)}\nIndice = inicio: 2018-01-01 final = 2021-12-31 pulando por mês\n\n"

# %%
import numpy as np
dias = pd.date_range(start='2018-1-1', end='2020-12-31')
n = dias.shape[0] #total de observações
dados = {
    'A': np.random.randint(low = 1, high = 1500, size = n),
    'B': np.random.normal(loc = 10, scale = 2, size = n),
    'C': np.random.uniform(low = 0, high = 1, size = n),
    'D': np.random.lognormal(mean = 4, sigma = 5, size = n),
    'E': np.random.standard_normal(size = n)}


df = pd.DataFrame(data = dados, index = dias)
df
# Out:
#                A          B         C            D         E
# 2018-01-01   123  12.357112  0.712175  9673.667983  0.440042
# 2018-01-02   161   6.609441  0.974666     0.591805 -0.028939
# 2018-01-03  1137  10.861252  0.323200  1157.195001  0.131008
# 2018-01-04  1088   9.950727  0.397890  9448.886844  1.119929
# 2018-01-05   410  10.986563  0.418927     5.157740 -0.188766
# ...          ...        ...       ...          ...       ...
# 2020-12-27   928  13.777771  0.806810   635.594322  1.563861
# 2020-12-28   968  12.154227  0.107991  4329.602036  1.644871
# 2020-12-29   954   6.128865  0.958451     0.051761  1.501947
# 2020-12-30  1151   9.463430  0.701194     0.094440  0.078290
# 2020-12-31   235   5.314169  0.807629     0.220222 -0.814598
#
# [1096 rows x 5 columns]

# %%
'''
Exercício 51
Com base no dataset anterior obtenha:

estatísticas descritivas de cada coluna;

informações do dataset;

matriz de correlação (use df.corr);

matriz de covariância (use df.cov).
'''
# Out:
# '\nExercício 51\nCom base no dataset anterior obtenha:\n\nestatísticas descritivas de cada coluna;\n\ninformações do dataset;\n\nmatriz de correlação (use df.corr);\n\nmatriz de covariância (use df.cov).\n'

# %%
print(df.describe().T)
print(df.info())
print(df.corr())
print(df.cov())
# Out:
#     count           mean           std       min         25%         50%  \
# A  1096.0     746.405109  4.368064e+02  1.000000  357.500000  742.500000
# B  1096.0       9.958311  2.003111e+00  3.616310    8.675519    9.947722
# C  1096.0       0.506764  2.846503e-01  0.000386    0.253374    0.516888
# D  1096.0  635730.879894  7.815501e+06  0.000006    1.789717   51.666749
# E  1096.0       0.028566  1.014025e+00 -3.961118   -0.653433    0.011474
#
#            75%           max
# A  1129.250000  1.498000e+03
# B    11.390528  1.702519e+01
# C     0.748416  9.970960e-01
# D  1428.247904  2.246342e+08
# E     0.748966  3.759119e+00
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2018-01-01 to 2020-12-31
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1096 non-null   int64
#  1   B       1096 non-null   float64
#  2   C       1096 non-null   float64
#  3   D       1096 non-null   float64
#  4   E       1096 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 51.4 KB
# None
#           A         B         C         D         E
# A  1.000000  0.036251 -0.035963 -0.054028  0.010424
# B  0.036251  1.000000 -0.034338  0.065457  0.019917
# C -0.035963 -0.034338  1.000000  0.039573  0.008902
# D -0.054028  0.065457  0.039573  1.000000 -0.038448
# E  0.010424  0.019917  0.008902 -0.038448  1.000000
#               A             B             C             D              E
# A  1.907999e+05  3.171846e+01     -4.471588 -1.844439e+08       4.617293
# B  3.171846e+01  4.012454e+00     -0.019579  1.024751e+06       0.040456
# C -4.471588e+00 -1.957890e-02      0.081026  8.803771e+04       0.002570
# D -1.844439e+08  1.024751e+06  88037.713798  6.108205e+13 -304702.432012
# E  4.617293e+00  4.045619e-02      0.002570 -3.047024e+05       1.028247

# %%
'''
Exercício 52
Use loop para iterar e imprimir os valores da Series abaixo. 
Seus valores seguem uma distribuição normal com média 10 e desvio padrão 0.5. 
Use np.random.seed(99) para reproduzir os valores deste exercício.
'''
# Out:
# '\nExercício 52\nUse loop para iterar e imprimir os valores da Series abaixo. \nSeus valores seguem uma distribuição normal com média 10 e desvio padrão 0.5. \nUse np.random.seed(99) para reproduzir os valores deste exercício.\n'

# %%
import numpy as np
np.random.seed(99)
n = np.random.normal(10, 0.5, size=10)
index = [chr(65+i) for i in range(10)]
Series = pd.Series(n, index=index, name = 'Data')
Series
# Out:
# A     9.928821
# B    11.028611
# C    10.141631
# D    10.664906
# E     9.922689
# F     9.965485
# G    10.377590
# H    10.412823
# I     9.943465
# J     8.816081
# Name: Data, dtype: float64

# %%
for numero in Series:
  print(numero)
# Out:
# 9.928820578649026
# 11.028610868790746
# 10.141630970553017
# 10.664905989128272
# 9.922689074476285
# 9.965484570434956
# 10.37759024253896
# 10.412823324256312
# 9.943465395149339
# 8.816081202635946

# %%
'''
Exercício 53
Ao iterar em objetos do tipo DataFrame obtemos os respectivos nomes de cada coluna. 
Mostre na tela o nome das colunas do DataFrame abaixo. Use:



dados = {
    'W': np.random.randint(1,10,10),
    'Z': np.random.uniform(0,10,10),
    'K': np.linspace(1,50,10),
    'J': np.arange(10),
    'L': np.random.beta(1,10,10),
    'M': np.random.exponential(1,10),
    'Y': np.random.randint(-50,-1,10)
}
'''
# Out:
# "\nExercício 53\nAo iterar em objetos do tipo DataFrame obtemos os respectivos nomes de cada coluna. \nMostre na tela o nome das colunas do DataFrame abaixo. Use:\n\n\n\ndados = {\n    'W': np.random.randint(1,10,10),\n    'Z': np.random.uniform(0,10,10),\n    'K': np.linspace(1,50,10),\n    'J': np.arange(10),\n    'L': np.random.beta(1,10,10),\n    'M': np.random.exponential(1,10),\n    'Y': np.random.randint(-50,-1,10)\n}\n"

# %%
dados = {
    'W': np.random.randint(1,10,10),
    'Z': np.random.uniform(0,10,10),
    'K': np.linspace(1,50,10),
    'J': np.arange(10),
    'L': np.random.beta(1,10,10),
    'M': np.random.exponential(1,10),
    'Y': np.random.randint(-50,-1,10)
}
data = pd.date_range(start='2020-12-01', periods=10)
colunas = ['W', 'Z', 'K', 'J', 'L', 'M', 'Y' ]
df = pd.DataFrame(dados, index = data, columns = colunas)
df
# Out:
#             W         Z          K  J         L         M   Y
# 2020-12-01  9  6.448347   1.000000  0  0.266708  0.346817 -10
# 2020-12-02  5  0.951816   6.444444  1  0.070572  0.174365 -23
# 2020-12-03  8  4.116632  11.888889  2  0.051361  0.362310 -50
# 2020-12-04  6  0.968653  17.333333  3  0.024803  1.267645 -36
# 2020-12-05  5  1.440110  22.777778  4  0.054955  3.169610  -9
# 2020-12-06  2  2.121962  28.222222  5  0.040888  0.015908 -18
# 2020-12-07  1  4.766562  33.666667  6  0.238423  0.374831 -14
# 2020-12-08  6  0.776138  39.111111  7  0.120640  0.050149 -23
# 2020-12-09  4  2.350438  44.555556  8  0.049486  2.077610 -33
# 2020-12-10  4  0.065530  50.000000  9  0.093592  1.183379 -37

# %%
for coluna in df:
  print(coluna)
# Out:
# W
# Z
# K
# J
# L
# M
# Y

# %%
'''
Exercício 54
Para iterar nas linhas de um DataFrame podemos usar as seguintes funções:

iteritems(): itera ao longo do par key,value (similar a um dicionário);

iterrows(): itera ao longo das das linhas (par index,Series);

itertuples(): itera ao longo das linhas como namedtuples.

Construa o DataFrame abaixo.

            A  B  C
2020-12-31  0  1  2
2021-01-31  1  4  4
2021-02-28  2  9  6

Construa um script para iterar sobre este, usando a função iteritems(). Resultado esperado:

A
	Soma dos valores: 3
	Valor mínimo: 0
	Valor máximo: 2
	Média dos valores: 1.0
	Desvio padrão: 1.0
 
B
	Soma dos valores: 14
	Valor mínimo: 1
	Valor máximo: 9
	Média dos valores: 4.67
	Desvio padrão: 4.04
 
C
	Soma dos valores: 12
	Valor mínimo: 2
	Valor máximo: 6
	Média dos valores: 4.0
	Desvio padrão: 2.0
'''
# Out:
# '\nExercício 54\nPara iterar nas linhas de um DataFrame podemos usar as seguintes funções:\n\niteritems(): itera ao longo do par key,value (similar a um dicionário);\n\niterrows(): itera ao longo das das linhas (par index,Series);\n\nitertuples(): itera ao longo das linhas como namedtuples.\n\nConstrua o DataFrame abaixo.\n\n            A  B  C\n2020-12-31  0  1  2\n2021-01-31  1  4  4\n2021-02-28  2  9  6\n\nConstrua um script para iterar sobre este, usando a função iteritems(). Resultado esperado:\n\nA\n\tSoma dos valores: 3\n\tValor mínimo: 0\n\tValor máximo: 2\n\tMédia dos valores: 1.0\n\tDesvio padrão: 1.0\n \nB\n\tSoma dos valores: 14\n\tValor mínimo: 1\n\tValor máximo: 9\n\tMédia dos valores: 4.67\n\tDesvio padrão: 4.04\n \nC\n\tSoma dos valores: 12\n\tValor mínimo: 2\n\tValor máximo: 6\n\tMédia dos valores: 4.0\n\tDesvio padrão: 2.0\n'

# %%
import numpy as np
dados = {
    'A': np.arange(3),
    'B': [n**2 for n in range(1,4)],
    'C': [n for n in range(1,7) if n%2==0]
}
data = pd.date_range(start='2020-12-1', periods=3, freq='M')
df = pd.DataFrame(dados, index = data)

for colunas, valores in df.iteritems():
  print(colunas)
  print('Soma dos valores: ', valores.sum())
  print('Valor Mínimo: ', valores.min())
  print('Valor máximos: ', valores.max())
  print('Média dos valores: ', valores.mean().round(2))
  print('Desvio Padrão: ', valores.std().round(2))
# Out:
# A
# Soma dos valores:  3
# Valor Mínimo:  0
# Valor máximos:  2
# Média dos valores:  1.0
# Desvio Padrão:  1.0
# B
# Soma dos valores:  14
# Valor Mínimo:  1
# Valor máximos:  9
# Média dos valores:  4.67
# Desvio Padrão:  4.04
# C
# Soma dos valores:  12
# Valor Mínimo:  2
# Valor máximos:  6
# Média dos valores:  4.0
# Desvio Padrão:  2.0

# %%
variavel = 'dia'
print('Bom @variavel' )
# Out:
# Bom @variavel

# %%
'''
Exercício 55
Construa o DataFrame abaixo.



            A   B   C
2021-01-01   1   2   3
2021-01-02   4   5   6
2021-01-03   7   8   9
2021-01-04  10  11  12
2021-01-05  13  14  15
2021-01-06  16  17  18
2021-01-07  19  20  21
2021-01-08  22  23  24
2021-01-09  25  26  27
2021-01-10  28  29  30
Posteriormente use iterrows() para obter a soma dos valores de cada linha:



01/01/2021
Soma: 6
 
02/01/2021
Soma: 15
 
03/01/2021
Soma: 24
 
04/01/2021
Soma: 33
 
05/01/2021
Soma: 42
 
06/01/2021
Soma: 51
 
07/01/2021
Soma: 60
 
08/01/2021
Soma: 69
 
09/01/2021
Soma: 78
 
10/01/2021
Soma: 87

'''
# Out:
# '\nExercício 55\nConstrua o DataFrame abaixo.\n\n\n\n            A   B   C\n2021-01-01   1   2   3\n2021-01-02   4   5   6\n2021-01-03   7   8   9\n2021-01-04  10  11  12\n2021-01-05  13  14  15\n2021-01-06  16  17  18\n2021-01-07  19  20  21\n2021-01-08  22  23  24\n2021-01-09  25  26  27\n2021-01-10  28  29  30\nPosteriormente use iterrows() para obter a soma dos valores de cada linha:\n\n\n\n01/01/2021\nSoma: 6\n \n02/01/2021\nSoma: 15\n \n03/01/2021\nSoma: 24\n \n04/01/2021\nSoma: 33\n \n05/01/2021\nSoma: 42\n \n06/01/2021\nSoma: 51\n \n07/01/2021\nSoma: 60\n \n08/01/2021\nSoma: 69\n \n09/01/2021\nSoma: 78\n \n10/01/2021\nSoma: 87\n\n'

# %%
dados = np.arange(1,31).reshape((10,3))
index = pd.date_range(start = '2021-01-01', periods = 10, freq='D')
df = pd.DataFrame(dados, index = index, columns = list('ABC'))
df
# Out:
#              A   B   C
# 2021-01-01   1   2   3
# 2021-01-02   4   5   6
# 2021-01-03   7   8   9
# 2021-01-04  10  11  12
# 2021-01-05  13  14  15
# 2021-01-06  16  17  18
# 2021-01-07  19  20  21
# 2021-01-08  22  23  24
# 2021-01-09  25  26  27
# 2021-01-10  28  29  30

# %%
for linha_indice, linha in df.iterrows():
  print(linha_indice.strftime('%d/%m/%Y'))
  print('Soma: '+str(linha.sum()))
  print()
# Out:
# 01/01/2021
# Soma: 6
#
# 02/01/2021
# Soma: 15
#
# 03/01/2021
# Soma: 24
#
# 04/01/2021
# Soma: 33
#
# 05/01/2021
# Soma: 42
#
# 06/01/2021
# Soma: 51
#
# 07/01/2021
# Soma: 60
#
# 08/01/2021
# Soma: 69
#
# 09/01/2021
# Soma: 78
#
# 10/01/2021
# Soma: 87

# %%
'''
exercício 56
Com base no DataFrame anterior use itertuples() para obter:

Pandas(Index=Timestamp('2021-01-01 00:00:00', freq='D'), A=1, B=2, C=3)
Pandas(Index=Timestamp('2021-01-02 00:00:00', freq='D'), A=4, B=5, C=6)
Pandas(Index=Timestamp('2021-01-03 00:00:00', freq='D'), A=7, B=8, C=9)
Pandas(Index=Timestamp('2021-01-04 00:00:00', freq='D'), A=10, B=11, C=12)
Pandas(Index=Timestamp('2021-01-05 00:00:00', freq='D'), A=13, B=14, C=15)
Pandas(Index=Timestamp('2021-01-06 00:00:00', freq='D'), A=16, B=17, C=18)
Pandas(Index=Timestamp('2021-01-07 00:00:00', freq='D'), A=19, B=20, C=21)
Pandas(Index=Timestamp('2021-01-08 00:00:00', freq='D'), A=22, B=23, C=24)
Pandas(Index=Timestamp('2021-01-09 00:00:00', freq='D'), A=25, B=26, C=27)
Pandas(Index=Timestamp('2021-01-10 00:00:00', freq='D'), A=28, B=29, C=30)
'''
# Out:
# "\nexercício 56\nCom base no DataFrame anterior use itertuples() para obter:\n\nPandas(Index=Timestamp('2021-01-01 00:00:00', freq='D'), A=1, B=2, C=3)\nPandas(Index=Timestamp('2021-01-02 00:00:00', freq='D'), A=4, B=5, C=6)\nPandas(Index=Timestamp('2021-01-03 00:00:00', freq='D'), A=7, B=8, C=9)\nPandas(Index=Timestamp('2021-01-04 00:00:00', freq='D'), A=10, B=11, C=12)\nPandas(Index=Timestamp('2021-01-05 00:00:00', freq='D'), A=13, B=14, C=15)\nPandas(Index=Timestamp('2021-01-06 00:00:00', freq='D'), A=16, B=17, C=18)\nPandas(Index=Timestamp('2021-01-07 00:00:00', freq='D'), A=19, B=20, C=21)\nPandas(Index=Timestamp('2021-01-08 00:00:00', freq='D'), A=22, B=23, C=24)\nPandas(Index=Timestamp('2021-01-09 00:00:00', freq='D'), A=25, B=26, C=27)\nPandas(Index=Timestamp('2021-01-10 00:00:00', freq='D'), A=28, B=29, C=30)\n"

# %%
import numpy as np
dias = pd.date_range(start='2021-1-1', periods = 10)
df = pd.DataFrame(
    data = np.arange(1, 31).reshape(10, 3), 
    columns = list('ABC'),
    index = dias)

for linha in df.itertuples():
  print(linha)
# Out:
# Pandas(Index=Timestamp('2021-01-01 00:00:00', freq='D'), A=1, B=2, C=3)
# Pandas(Index=Timestamp('2021-01-02 00:00:00', freq='D'), A=4, B=5, C=6)
# Pandas(Index=Timestamp('2021-01-03 00:00:00', freq='D'), A=7, B=8, C=9)
# Pandas(Index=Timestamp('2021-01-04 00:00:00', freq='D'), A=10, B=11, C=12)
# Pandas(Index=Timestamp('2021-01-05 00:00:00', freq='D'), A=13, B=14, C=15)
# Pandas(Index=Timestamp('2021-01-06 00:00:00', freq='D'), A=16, B=17, C=18)
# Pandas(Index=Timestamp('2021-01-07 00:00:00', freq='D'), A=19, B=20, C=21)
# Pandas(Index=Timestamp('2021-01-08 00:00:00', freq='D'), A=22, B=23, C=24)
# Pandas(Index=Timestamp('2021-01-09 00:00:00', freq='D'), A=25, B=26, C=27)
# Pandas(Index=Timestamp('2021-01-10 00:00:00', freq='D'), A=28, B=29, C=30)

# %%
'''
Exercício 57
Ordene o DataFrame abaixo pelo índice.
import pandas as pd
import numpy as np
dias = pd.date_range(start = '2020-1-1', periods = 10).to_numpy()
np.random.shuffle(dias)
df = pd.DataFrame(
    data = np.random.normal(10,3.5,(10,3)),
    columns = list('ABC'),
    index = dias)
'''
# Out:
# "\nExercício 57\nOrdene o DataFrame abaixo pelo índice.\nimport pandas as pd\nimport numpy as np\ndias = pd.date_range(start = '2020-1-1', periods = 10).to_numpy()\nnp.random.shuffle(dias)\ndf = pd.DataFrame(\n    data = np.random.normal(10,3.5,(10,3)),\n    columns = list('ABC'),\n    index = dias)\n"

# %%
import pandas as pd
import numpy as np
dias = pd.date_range(start = '2020-1-1', periods = 10).to_numpy()
np.random.shuffle(dias)
df = pd.DataFrame(
    data = np.random.normal(10,3.5,(10,3)),
    columns = list('ABC'),
    index = dias)

df.sort_index()
# Out:
#                     A          B          C
# 2020-01-01  14.900063  11.548614   8.668812
# 2020-01-02  14.857492   3.424100   7.426703
# 2020-01-03  10.087231   5.744381   9.600521
# 2020-01-04   4.593295  14.522055   7.318182
# 2020-01-05   7.039521   8.232099  10.898853
# 2020-01-06  14.271575  12.343642  10.468822
# 2020-01-07  15.119690   9.310857   6.812875
# 2020-01-08  10.679169   8.717990  12.242658
# 2020-01-09  12.370805   8.141161  16.700725
# 2020-01-10   8.790874   7.298284   9.010724

# %%
'''
Exercício 58
O dataset abaixo armazena informações do campeonato brasileiro de futebol, série A, entre 2017 a 2019. Com base nestes dados responda:

qual a média de pontos de cada time entre 2017-2019?

qual a pontuação máxima e mínima por ano?

qual a média de pontos por ano, dentre todos os times selecionados?

quantos times estiveram no Top 5 em cada ano?

obtenha estatísticas descritivas da pontuação para cada time (média, máximo, mínimo, desvio padrão, mediana), para o recorte temporal estabelecido.

Use a função groupby().
'''
# Out:
# '\nExercício 58\nO dataset abaixo armazena informações do campeonato brasileiro de futebol, série A, entre 2017 a 2019. Com base nestes dados responda:\n\nqual a média de pontos de cada time entre 2017-2019?\n\nqual a pontuação máxima e mínima por ano?\n\nqual a média de pontos por ano, dentre todos os times selecionados?\n\nquantos times estiveram no Top 5 em cada ano?\n\nobtenha estatísticas descritivas da pontuação para cada time (média, máximo, mínimo, desvio padrão, mediana), para o recorte temporal estabelecido.\n\nUse a função groupby().\n'

# %%
dados = {
    'Pontos': [56, 74, 63, 63, 72, 50, 63, 44, 80],
    'Rank': [8, 3, 6, 2, 1, 13, 5, 13, 1],
    'Ano': [2019, 2019, 2019, 2017, 2017, 2017, 2018, 2018, 2018],
    'Times': ['Corinthians', 'Palmeiras', 'São Paulo', 'Palmeiras', 'Corinthians', 'São Paulo', 'São Paulo', 'Corinthians', 'Palmeiras']
}

df = pd.DataFrame(dados)
df
# Out:
#    Pontos  Rank   Ano        Times
# 0      56     8  2019  Corinthians
# 1      74     3  2019    Palmeiras
# 2      63     6  2019    São Paulo
# 3      63     2  2017    Palmeiras
# 4      72     1  2017  Corinthians
# 5      50    13  2017    São Paulo
# 6      63     5  2018    São Paulo
# 7      44    13  2018  Corinthians
# 8      80     1  2018    Palmeiras

# %%
#qual a média de pontos de cada time entre 2017-2019?
df.groupby('Times')['Pontos'].mean().round(2)
# Out:
# Times
# Corinthians    57.33
# Palmeiras      72.33
# São Paulo      58.67
# Name: Pontos, dtype: float64

# %%
#qual a pontuação máxima e mínima por ano?
df.groupby('Ano')[['Pontos']].agg([np.min,np.max])
# Out:
#      Pontos
#        amin amax
# Ano
# 2017     50   72
# 2018     44   80
# 2019     56   74

# %%
#qual a média de pontos por ano, dentre todos os times selecionados?
df.groupby('Ano')['Pontos'].mean().round(2)
# Out:
# Ano
# 2017    61.67
# 2018    62.33
# 2019    64.33
# Name: Pontos, dtype: float64

# %%
#quantos times estiveram no Top 5 em cada ano?
df[df['Rank'] <= 5].groupby('Ano')['Times'].count()
# Out:
# Ano
# 2017    2
# 2018    2
# 2019    1
# Name: Times, dtype: int64

# %%
#obtenha estatísticas descritivas da pontuação para cada time (média, máximo, mínimo, desvio padrão, mediana), para o recorte temporal estabelecido.
df.groupby('Times')['Pontos'].agg([np.mean, np.std, np.var, np.median])
# Out:
#                   mean        std         var  median
# Times
# Corinthians  57.333333  14.047538  197.333333    56.0
# Palmeiras    72.333333   8.621678   74.333333    74.0
# São Paulo    58.666667   7.505553   56.333333    63.0

# %%
'''
Exercício 59


Construa os objetos do tipo DataFrame a seguir.
data1 = {
    'A': ['A0','A1','A2','A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    }
 
data2 = {
    'A':['A4', 'A5', 'A6', 'A7'],
    'B':['B4', 'B5', 'B6', 'B7'],
    'C':['C4', 'C5', 'C6', 'C7'],
    }
 
index = [1, 2, 3, 4]


Use a função pd.concat() para concatenar os dados e obtenha:
'''

# %%
data1 = {
    'A': ['A0','A1','A2','A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    }
 
data2 = {
    'A':['A4', 'A5', 'A6', 'A7'],
    'B':['B4', 'B5', 'B6', 'B7'],
    'C':['C4', 'C5', 'C6', 'C7'],
    }
 
index = [1, 2, 3, 4]

df1 = pd.DataFrame(data1, index)
df2 = pd.DataFrame(data2, index)

# %%
A = pd.concat([df1, df2], keys = ['Grupo A', 'Grupo B'])
A
# Out:
#             A   B   C
# Grupo A 1  A0  B0  C0
#         2  A1  B1  C1
#         3  A2  B2  C2
#         4  A3  B3  C3
# Grupo B 1  A4  B4  C4
#         2  A5  B5  C5
#         3  A6  B6  C6
#         4  A7  B7  C7

# %%
B =  pd.concat([df1, df2], ignore_index = True)
B
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5
# 6  A6  B6  C6
# 7  A7  B7  C7

# %%
C = pd.concat([df1, df2], axis = 1)
C
# Out:
#     A   B   C   A   B   C
# 1  A0  B0  C0  A4  B4  C4
# 2  A1  B1  C1  A5  B5  C5
# 3  A2  B2  C2  A6  B6  C6
# 4  A3  B3  C3  A7  B7  C7

# %%
D = pd.concat([df1, df2], axis = 1, keys = ['Grupo A', 'Grupo B'])
D
# Out:
#   Grupo A         Grupo B
#         A   B   C       A   B   C
# 1      A0  B0  C0      A4  B4  C4
# 2      A1  B1  C1      A5  B5  C5
# 3      A2  B2  C2      A6  B6  C6
# 4      A3  B3  C3      A7  B7  C7

# %%
'''
Exercício 60
Use os objetos do tipo DataFrame a seguir e use a função append() do pandas para concatenar os dados e obtenha:

import pandas as pd
index = [1, 2, 3]
df1 = pd.DataFrame({
    'A': ['A0','A1','A2',],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2'],
    }, index = index)
 
df2 = pd.DataFrame({
    'A':['A3', 'A4', 'A5'],
    'B':['B3', 'B4', 'B5'],
    'C':['C3', 'C4', 'C5'],
    }, index = index)
 
df3 = pd.DataFrame({
    'A': ['A6', 'A7', 'A8'],
    'B': ['B6', 'B7', 'B8'],
    'C': ['C6', 'C7', 'C8']
    }, index = index)
'''

# %%
index = [1, 2, 3]
df1 = pd.DataFrame({
    'A': ['A0','A1','A2',],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2'],
    }, index = index)
 
df2 = pd.DataFrame({
    'A':['A3', 'A4', 'A5'],
    'B':['B3', 'B4', 'B5'],
    'C':['C3', 'C4', 'C5'],
    }, index = index)
 
df3 = pd.DataFrame({
    'A': ['A6', 'A7', 'A8'],
    'B': ['B6', 'B7', 'B8'],
    'C': ['C6', 'C7', 'C8']
    }, index = index)

# %%
data1 = df1.append(df2, ignore_index = True)
data1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 3  A3  B3  C3
# 4  A4  B4  C4
# 5  A5  B5  C5

# %%
data2 = df1.append([df2, df3])
data2
# Out:
#     A   B   C
# 1  A0  B0  C0
# 2  A1  B1  C1
# 3  A2  B2  C2
# 1  A3  B3  C3
# 2  A4  B4  C4
# 3  A5  B5  C5
# 1  A6  B6  C6
# 2  A7  B7  C7
# 3  A8  B8  C8

# %%
'''
Exercício 61
Mostre que o dataset abaixo possui missing data. Siga os seguinte passos:

Construa o DataFrame;

Use a função isna(), isnull(), notna() ou notnull() para verificar NaN em cada coluna do dataset;

Use a função dropna() para remover as linhas com dados ausentes do dataset.
data = {
    'A': [10, np.nan, 35, 47, 17, 13],
    'B': ['A', np.nan, 'B', 'A', 'A', np.nan],
    'C': [139, np.nan, np.nan, 199, 111, 140]}
'''

# %%
import numpy as np
data = {
    'A': [10, np.nan, 35, 47, 17, 13],
    'B': ['A', np.nan, 'B', 'A', 'A', np.nan],
    'C': [139, np.nan, np.nan, 199, 111, 140]}

index = pd.date_range(start='2020-1-1', end='2020-1-6', freq = 'D')
df = pd.DataFrame(data, index = index)
df
# Out:
#                A    B      C
# 2020-01-01  10.0    A  139.0
# 2020-01-02   NaN  NaN    NaN
# 2020-01-03  35.0    B    NaN
# 2020-01-04  47.0    A  199.0
# 2020-01-05  17.0    A  111.0
# 2020-01-06  13.0  NaN  140.0

# %%
#verificando missing (datos nulos)
df.isna()
# Out:
#                 A      B      C
# 2020-01-01  False  False  False
# 2020-01-02   True   True   True
# 2020-01-03  False  False   True
# 2020-01-04  False  False  False
# 2020-01-05  False  False  False
# 2020-01-06  False   True  False

# %%
#removendo linhas do missing (dados nulos)
df.dropna(axis = 0)
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0

# %%
'''
Exercício 62
Crie uma função que recebe um objeto DataFrame e retorne o percentual de missings em cada coluna do dataset. 
objeto for da classe pandas.core.frame.DataFrame mostre o cálculo de missing data, caso contrário retorne None. 
Teste a função com o dataset anterior.
'''

# %%
import numpy as np
def mostrar_nan(data_frame):
  if isinstance(data_frame, pd.core.frame.DataFrame):
    return ((data_frame.isna().sum()/data_frame.shape[0]).round(3))*100
  else:
    return None

# %%
mostrar_nan(df)
# Out:
# A    16.7
# B    33.3
# C    33.3
# dtype: float64

# %%
'''
Exercício 63
Com o dataset do exercício 61 substitua todos os NaN pelo valor 0.
'''

# %%
df.fillna(0, inplace = True)
df
# Out:
#                A  B      C
# 2020-01-01  10.0  A  139.0
# 2020-01-02   0.0  0    0.0
# 2020-01-03  35.0  B    0.0
# 2020-01-04  47.0  A  199.0
# 2020-01-05  17.0  A  111.0
# 2020-01-06  13.0  0  140.0

# %%
'''
Exercício 64
Com base no DataFrame abaixo use a função fillna() para preenchar os dados ausentes em cada coluna, 
de acordo as seguintes regras:

coluna A: substitua os NaN pela média dos valores;

coluna B: substitua os NaN pela moda dos valores;

coluna C: substitua os NaN pelo categoria 'A';

coluna D: substitua os NaN pela mediana dos valores.
'''

# %%
import numpy as np

index = pd.date_range(start = '2021-12-1', end = '2021-12-8')
data = {
    'A':[np.nan, 10, 11, 9, 17, 21, np.nan, np.nan],
    'B':[np.nan, np.nan, 1, 1, 1, 0, np.nan, 1],
    'C':['A', 'B', 'B','A',np.nan, np.nan,np.nan,'A'],
    'D':[169, 133, np.nan, 172, np.nan, 133, 174, 170]}
df = pd.DataFrame(data, index)
df
# Out:
#                A    B    C      D
# 2021-12-01   NaN  NaN    A  169.0
# 2021-12-02  10.0  NaN    B  133.0
# 2021-12-03  11.0  1.0    B    NaN
# 2021-12-04   9.0  1.0    A  172.0
# 2021-12-05  17.0  1.0  NaN    NaN
# 2021-12-06  21.0  0.0  NaN  133.0
# 2021-12-07   NaN  NaN  NaN  174.0
# 2021-12-08   NaN  1.0    A  170.0

# %%
fill_missing = {
    #coluna A: substitua os NaN pela média dos valores;
    'A': df['A'].mean(),
    #coluna B: substitua os NaN pela moda dos valores;
    'B': df['B'].mode()[0],
    #coluna C: substitua os NaN pelo categoria 'A';
    'C': 'A',
    #coluna D: substitua os NaN pela mediana dos valores.
    'D': df['D'].median()
}
df.fillna(fill_missing, inplace = True)
df
# Out:
#                A    B  C      D
# 2021-12-01  13.6  1.0  A  169.0
# 2021-12-02  10.0  1.0  B  133.0
# 2021-12-03  11.0  1.0  B  169.5
# 2021-12-04   9.0  1.0  A  172.0
# 2021-12-05  17.0  1.0  A  169.5
# 2021-12-06  21.0  0.0  A  133.0
# 2021-12-07  13.6  1.0  A  174.0
# 2021-12-08  13.6  1.0  A  170.0

# %%
'''
Exercício 65
Com base no DataFrame abaixo:

remova as linhas duplicadas;

altere o ID da brand W para 11;

ordene o DataFrame pela coluna Rating;

Mude o índice do DataFrame para a coluna 'ID';

converta o DataFrame para um dicionário e armazene em uma variável.

import pandas as pd
 
data = {
    'Brand': ['A', 'A', 'D', 'W', 'K'],
    'ID': [1, 1, 3, 5, 7],
    'Rating':[3.5, 3.5, 4, 8.2, 1]}
 
df = pd.DataFrame(data)
'''

# %%
data = {
    'Brand': ['A', 'A', 'D', 'W', 'K'],
    'ID': [1, 1, 3, 5, 7],
    'Rating':[3.5, 3.5, 4, 8.2, 1]}
 
df = pd.DataFrame(data)

# %%
#remova as linhas duplicadas;
df.drop_duplicates()
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 2     D   3     4.0
# 3     W   5     8.2
# 4     K   7     1.0

# %%
#altere o ID da brand W para 11;
df.at[3, 'ID'] = 11
df
# Out:
#   Brand  ID  Rating
# 0     A   1     3.5
# 1     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2
# 4     K   7     1.0

# %%
#ordene o DataFrame pela coluna Rating;
df.sort_values(by = 'Rating')
# Out:
#   Brand  ID  Rating
# 4     K   7     1.0
# 0     A   1     3.5
# 1     A   1     3.5
# 2     D   3     4.0
# 3     W  11     8.2

# %%
#Mude o índice do DataFrame para a coluna 'ID';
df.set_index('ID')
# Out:
#    Brand  Rating
# ID
# 1      A     3.5
# 1      A     3.5
# 3      D     4.0
# 11     W     8.2
# 7      K     1.0

# %%
#converta o DataFrame para um dicionário e armazene em uma variável.
dicionario = df.to_dict()
dicionario
# Out:
# {'Brand': {0: 'A', 1: 'A', 2: 'D', 3: 'W', 4: 'K'},
#  'ID': {0: 1, 1: 1, 2: 3, 3: 11, 4: 7},
#  'Rating': {0: 3.5, 1: 3.5, 2: 4.0, 3: 8.2, 4: 1.0}}

# %%
'''
Exercícios 66-70
1. Use a função pd.read_csv() para carregar o dataset insurance.csv, 
anexo nesta aula; armazene em uma variável;

2.  Mostre a quantidade de linhas e colunas (shape);

3. Mostre informações básicas do dataset com a função info();

4. Mostre o dtype de cada coluna;

5. Mostre as colunas do dataset;

6. Mostre informações estatísticas da coluna 'age';

7. Imprima os valores únicos de cada coluna, com exceção da coluna bmi;

8. Mostre a distribuição das idades;

9. Verifique se há missing no dataset;

10. Verifique se há linhas duplicadas no DataFrame, caso existam linhas duplicadas delete;

11. Mostre as variáveis com o tipo de dado object;

12. Mostre apenas as colunas numéricas do dataset;

13. Converta as colunas numéricas para uma lista;

14. Converta as colunas não numéricas para uma lista;

15. Converta o dtype das variáveis sex, smoker e region para category; confira novamente o dtype das colunas;

16. Mostre estatísticas descritivas das colunas categóricas;

17. Mostre estatísticas descritivas das colunas numéricas;

18. Mostre a proporção entre homens e mulheres;

19. Retorne todas as pessoas com idade igual ou superior a 62 anos;

20. Retorne todas as pessoas com idade igual a 18 anos;

21. Conte quantas pessoas residem na região 'southwest';

22. Ordene o DataFrame pela coluna 'age' em ordem crescente;

23. Visualize a distribuição das idades por meio de um plot boxplot;

24. Visualize a distribuição das idades usando histograma.
'''

# %%
#Use a função pd.read_csv() para carregar o dataset insurance.csv, anexo nesta aula; armazene em uma variável;
Dados = pd.read_csv('insurance.csv')
Dados.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Mostre a quantidade de linhas e colunas (shape);
Dados.shape
# Out:
# (1338, 7)

# %%
#Mostre informações básicas do dataset com a função info();
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#Mostre o dtype de cada coluna;
Dados.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#Mostre as colunas do dataset;
Dados.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#Mostre informações estatísticas da coluna 'age';
Dados['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
#Imprima os valores únicos de cada coluna, com exceção da coluna bmi;
for coluna in Dados:
  if coluna == 'bmi':
    continue
  else:
    print(coluna.upper())
    print(Dados[coluna].unique())
    print()
# Out:
# AGE
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
# SEX
# ['female', 'male']
# Categories (2, object): ['female', 'male']
#
# CHILDREN
# [0 1 3 2 5 4]
#
# SMOKER
# ['yes', 'no']
# Categories (2, object): ['no', 'yes']
#
# REGION
# ['southwest', 'southeast', 'northwest', 'northeast']
# Categories (4, object): ['northeast', 'northwest', 'southeast', 'southwest']
#
# CHARGES
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %%
#Mostre a distribuição das idades;
Dados['age'].value_counts().sort_values()
# Out:
# 64    22
# 61    23
# 62    23
# 63    23
# 60    23
# 39    25
# 35    25
# 38    25
# 36    25
# 58    25
# 59    25
# 37    25
# 32    26
# 33    26
# 55    26
# 34    26
# 56    26
# 57    26
# 41    27
# 40    27
# 31    27
# 44    27
# 42    27
# 30    27
# 43    27
# 29    27
# 49    28
# 54    28
# 53    28
# 21    28
# 22    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 26    28
# 52    29
# 48    29
# 20    29
# 45    29
# 46    29
# 47    29
# 51    29
# 50    29
# 19    68
# 18    69
# Name: age, dtype: int64

# %%
#Verifique se há missing no dataset;
Dados.isna()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
#Verifique se há linhas duplicadas no DataFrame, caso existam linhas duplicadas delete;
Dados[Dados.duplicated()]
#deletando as linhas duplicadas
Dados = Dados.drop_duplicates()
Dados
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
#Mostre as variáveis com o tipo de dado object;
Dados.select_dtypes(include = 'object')
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1337 rows x 3 columns]

# %%
#Mostre apenas as colunas numéricas do dataset;
Dados.select_dtypes(include = ['int', 'float'])
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1337 rows x 4 columns]

# %%
#Converta as colunas numéricas para uma lista;
colunas_numericas = Dados.select_dtypes(include = ['int', 'float']).columns.to_list()
colunas_numericas
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
#Converta as colunas não numéricas para uma lista;
colunas_categoricas = Dados.select_dtypes(include = 'object').columns.to_list()
colunas_categoricas
# Out:
# []

# %%
#Converta o dtype das variáveis sex, smoker e region para category; confira novamente o dtype das colunas;
for col in colunas_categoricas:
    Dados[col] = Dados[col].astype('category')
Dados.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
#Mostre estatísticas descritivas das colunas categóricas;
Dados[colunas_categoricas].describe().T
# Out:
#        count unique        top  freq
# sex     1337      2       male   675
# smoker  1337      2         no  1063
# region  1337      4  southeast   364

# %%
#Mostre estatísticas descritivas das colunas numéricas;
Dados[colunas_numericas].describe().T
# Out:
#            count          mean           std        min       25%        50%  \
# age       1337.0     39.222139     14.044333    18.0000    27.000    39.0000
# bmi       1337.0     30.663452      6.100468    15.9600    26.290    30.4000
# children  1337.0      1.095737      1.205571     0.0000     0.000     1.0000
# charges   1337.0  13279.121487  12110.359656  1121.8739  4746.344  9386.1613
#
#                   75%          max
# age          51.00000     64.00000
# bmi          34.70000     53.13000
# children      2.00000      5.00000
# charges   16657.71745  63770.42801

# %%
#Mostre a proporção entre homens e mulheres;
Dados['sex'].value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
#Retorne todas as pessoas com idade igual ou superior a 62 anos;
Dados.query('age >=62')
#ou
Dados[Dados['age']>= 62]
#ou
Dados.loc[Dados['age']>= 62]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 26     63  female  23.085         0     no  northeast  14451.83515
# 33     63    male  28.310         0     no  northwest  13770.09790
# 36     62  female  32.965         3     no  northwest  15612.19335
# 62     64    male  24.700         1     no  northwest  30166.61817
# ...   ...     ...     ...       ...    ...        ...          ...
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1322   62    male  38.830         0     no  southeast  12981.34570
#
# [68 rows x 7 columns]

# %%
#Retorne todas as pessoas com idade igual a 18 anos;
Dados.query('age == 18')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 46     18  female  38.665         2     no  northeast   3393.35635
# 50     18  female  35.625         0     no  northeast   2211.13075
# ...   ...     ...     ...       ...    ...        ...          ...
# 1296   18    male  26.125         0     no  northeast   1708.92575
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
#
# [69 rows x 7 columns]

# %%
# Conte quantas pessoas residem na região 'southwest';
Dados.loc[Dados['region'] == 'southwest'].shape[0]
# Out:
# 325

# %%
#Ordene o DataFrame pela coluna 'age' em ordem crescente;
Dados.sort_values(by = 'age', ascending = True)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 866    18    male  37.290         0     no  southeast   1141.44510
# 911    18    male  31.730         0    yes  northeast  33732.68670
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 781    18    male  41.140         0     no  southeast   1146.79660
# 600    18  female  39.160         0     no  southeast   1633.04440
# ...   ...     ...     ...       ...    ...        ...          ...
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 378    64  female  30.115         3     no  northwest  16455.70785
# 752    64    male  37.905         0     no  northwest  14210.53595
# 335    64    male  34.500         0     no  southwest  13822.80300
# 664    64  female  22.990         0    yes  southeast  27037.91410
#
# [1337 rows x 7 columns]

# %%
#Visualize a distribuição das idades por meio de um plot boxplot;
Dados['age'].plot(kind='box')

# %%
#Visualize a distribuição das idades usando histograma.
Dados['age'].plot(kind='hist', bins = 30)
